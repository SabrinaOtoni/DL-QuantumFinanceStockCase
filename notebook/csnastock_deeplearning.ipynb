# %% [markdown]
# # MBA em Ciência de Dados e Inteligência Artificial - FIAP - 2024
# # Projeto Integrado - Deep Learning

# %% [markdown]
# ## Descrição do Projeto:
#
# A QuantumFinance está desejando construir um fundo de ações baseado em modelos de Deep Learning. A ideia é desenvolver um modelo que tenha como saída a compra ou venda de uma determinada ação baseado na movimentação do mercado nos últimos 15 dias.

# %% [markdown]
# ## O Desafio:
# A empresa deseja um modelo de Deep Learning que seja um ‘perseguidor de tendencia’, ou seja, se o papel sobe o modelo deve comprar, se o papel desce o
# modelo deve vender. Para isso a QuantumFinance contratou economistas que fizerem a rotulagem dos dados baseado no valor de fechamento dos ativos. Inicialmente foi feita uma suavização dos preços de fechamento, e por se tratar de um assunto sigiloso, não foi informada a técnica de suavização utilizada. O próximo passo foi realizar a rotulagem dia a dia, para verificar qual devemos comprar e qual devemos vender.

# %% [markdown]
# Para esse notebook, contemplo uma arquitetura simples de redes utilizando CNN + LSTM. Essa arquitetura foi baseada em artigos para finalidade de estudo, disponíveis através do arquivo README.md, utilizando a ação VALE3 - Vale do Rio Doce para ajustes. Como bônus, abordo outras 3 ações (BBAS3 - Banco do Brasil, CSNA3 - Companhia Siderúrgica Nacional, PETR4 - Petrobras) para avaliar como a rede se comporta com outras ações.

# %%
from pathlib import Path 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.graph_objects as go

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import ConfusionMatrixDisplay, recall_score, precision_score

from keras.models import Sequential
from keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, LSTM, Bidirectional
from keras.regularizers import l1_l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras_tuner.tuners import Hyperband

import warnings
warnings.filterwarnings('ignore')

# %%
datapath = Path('../data')
modelpath = Path('../model')

# %%
data = pd.read_csv(f'{datapath}/csv/CSNA3train.csv')
data = data[['Date', 'Smoothed_Close', 'Label']]
data.head()
# Out:
#          Date  Smoothed_Close  Label
# 0  2000-01-24        1.588954     -1
# 1  2000-01-26        1.569864     -1
# 2  2000-01-27        1.550466     -1
# 3  2000-01-28        1.531815     -1
# 4  2000-01-31        1.511619     -1

# %%
data['Label'].value_counts()
# Out:
# -1    2655
#  1    2088
# Name: Label, dtype: int64

# %%
class LabelTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        X = X.copy()
        X.loc[X['Label'] == -1, 'Label'] = 0
        return X

# %%
data_test = pd.read_csv(f'{datapath}/csv/CSNA3test.csv')
data_test = data_test[['Smoothed_Close', 'Label']]

# %%
label_transformer = LabelTransformer()
data = label_transformer.fit_transform(data)
data_test = label_transformer.transform(data_test)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4743 entries, 0 to 4742
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            4743 non-null   object
#  1   Smoothed_Close  4743 non-null   float64
#  2   Label           4743 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 111.3+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Year'] = data['Date'].dt.year

# %%
fig = go.Figure()

for year in data['Year'].unique():
    year_data = data[data['Year'] == year]
    fig.add_trace(go.Scatter(x=year_data['Date'], y=year_data['Smoothed_Close'],
                             mode='lines', name=str(year)))

for label, name, color in zip([0, 1], ['Venda', 'Compra'], ['red', 'green']):
    label_data = data[data['Label'] == label]
    fig.add_trace(go.Scatter(x=label_data['Date'], y=label_data['Smoothed_Close'],
                             mode='markers', name=name, marker_color=color))

fig.update_layout(title='CSNA3 - Companhia Siderúrgica Nacional',
                  xaxis_title='Anos',
                  yaxis_title='Preços de Fechamento',
                  legend_title='Legenda')

fig.show()

# %%
data.drop(['Date', 'Year'], axis=1, inplace=True)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close = scaler.fit_transform(data[['Smoothed_Close']])
scaled_close_test = scaler.transform(data_test[['Smoothed_Close']])

# %%
data['Scaled_Close'] = scaled_close.flatten()
data_test['Scaled_Close'] = scaled_close_test.flatten()

# %%
def create_window(data, label, window_size=15):
    X, y = [], []
    cumulative_avg = np.cumsum(data) / np.arange(1, len(data) + 1)

    for i in range(len(data) - window_size):
        window = data[i:(i + window_size)]
        window = np.append(window, cumulative_avg[i + window_size - 1])
        window = np.expand_dims(window, axis=-1)
        X.append(window)
        y.append(label[i + window_size])

    return np.array(X), np.array(y)

# %%
X_train, y_train = create_window(data=data['Scaled_Close'], label=data['Label'], window_size=15)
X_test, y_test = create_window(data=data['Scaled_Close'], label=data['Label'], window_size=15)

# %%
def rede_cnnTrading(hp):
    model = Sequential()
    model.add(Conv1D(
        filters=hp.Int('filters_1', min_value=32, max_value=64, step=32),
        kernel_size=hp.Choice('kernel_size_1', values=[2, 3]),
        activation=hp.Choice('activ1', values=['relu', 'tanh', 'elu']),
        padding='same', kernel_initializer='he_uniform', input_shape=(16, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=hp.Choice('pool1', values=[1, 2])))
    # model.add(Conv1D(
    #     filters=hp.Int('filters_2', min_value=32, max_value=128, step=32),
    #     kernel_size=hp.Choice('kernel_size_2', values=[2, 3]),
    #     activation=hp.Choice('activ2', values=['relu', 'tanh', 'elu']),
    #     padding='same', kernel_initializer='he_uniform'))
    # model.add(BatchNormalization())
    # model.add(MaxPooling1D(pool_size=hp.Choice('poo2', values=[1, 2])))
    # model.add(Conv1D(
    #     filters=hp.Int('filters_3', min_value=32, max_value=64, step=32),
    #     kernel_size=hp.Choice('kernel_size_3', values=[2, 3]),
    #     activation=hp.Choice('activ3', values=['relu', 'tanh', 'elu']),
    #     padding='same', kernel_initializer='he_uniform'))
    # model.add(MaxPooling1D(pool_size=hp.Choice('poo3', values=[1, 2])))
    # model.add(Bidirectional(LSTM(
    #     units=hp.Int('lstm_units1', min_value=50, max_value=100, step=50),
    #     activation=hp.Choice('actv3', values=['relu', 'tanh', 'elu']), return_sequences=True, kernel_initializer='he_uniform')))
    # model.add(Dropout(hp.Float('dropout_rate1', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(Bidirectional(LSTM(
        units=hp.Int('lstm_units2', min_value=50, max_value=100, step=50),
        activation=hp.Choice('actv4', values=['relu', 'tanh', 'elu']), kernel_initializer='he_uniform')))
    # model.add(Dropout(hp.Float('dropout_rate2', min_value=0.0, max_value=0.5, step=0.1)))
    # model.add(TimeDistributed(Dense(units=1, activation=hp.Choice('activ2', values=['relu', 'tanh']), kernel_initializer='he_uniform')))
    model.add(Dropout(hp.Float('dropout_rate3', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(Dense(units=1, activation='sigmoid', kernel_initializer='he_uniform',
                                    kernel_regularizer=l1_l2(l1=hp.Float('l1', min_value=0.0, max_value=0.05, step=0.01), l2=hp.Float('l1', min_value=0.0, max_value=0.05, step=0.01))))
    model.compile(optimizer=Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-3, sampling='LOG')),
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = Hyperband(
    rede_cnnTrading,
    objective='val_accuracy',
    max_epochs=100,
    directory=f'{modelpath}',
    project_name='hparam_tuning')
# Out:
# Reloading Tuner from ..\model\hparam_tuning\tuner0.json

# %%
es = EarlyStopping(monitor='loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, verbose=1)
mcp = ModelCheckpoint(filepath=f'{modelpath}/pesosCSNA.h5', monitor='loss', save_best_only=True, verbose=1, mode='max')
callbacks = [es, rlr, mcp]

# %%
train_size = int(len(X_train) * 0.8)
X_train_split, X_val_split = X_train[:train_size], X_train[train_size:]
y_train_split, y_val_split = y_train[:train_size], y_train[train_size:]

# %%
tuner.search(X_train, y_train, validation_data=(X_val_split, y_val_split), epochs=100, callbacks=[es, rlr, mcp], batch_size=1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='elu', padding='same', kernel_initializer='he_uniform', input_shape=(16, 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(units=50, activation='relu', kernel_initializer='he_uniform')))
model.add(Dropout(0.3))
model.add(Dense(units=1, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l1_l2(l1=0.02, l2=0.02)))
model.compile(optimizer=Adam(learning_rate=0.00058622), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TradingClassifierCSNA = model.fit(X_train_split, y_train_split, epochs=200, batch_size=1, validation_data=(X_val_split, y_val_split), callbacks=[es, rlr, mcp])
# Out:
# Epoch 1/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.5883 - accuracy: 0.7648
# Epoch 1: loss improved from -inf to 0.58902, saving model to ..\model\pesosCSNA.h5
# 3782/3782 [==============================] - 18s 4ms/step - loss: 0.5890 - accuracy: 0.7647 - val_loss: 6.5013 - val_accuracy: 0.6490 - lr: 5.8622e-04
# Epoch 2/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8342
# Epoch 2: loss did not improve from 0.58902
# 3782/3782 [==============================] - 16s 4ms/step - loss: 0.4215 - accuracy: 0.8342 - val_loss: 2.1346 - val_accuracy: 0.6311 - lr: 5.8622e-04
# Epoch 3/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.3311 - accuracy: 0.8707
# Epoch 3: loss did not improve from 0.58902
# 3782/3782 [==============================] - 16s 4ms/step - loss: 0.3313 - accuracy: 0.8707 - val_loss: 2.4561 - val_accuracy: 0.7273 - lr: 5.8622e-04
# Epoch 4/200
# 3769/3782 [============================>.] - ETA: 0s - loss: 0.3053 - accuracy: 0.8899
# Epoch 4: loss did not improve from 0.58902
# 3782/3782 [==============================] - 16s 4ms/step - loss: 0.3056 - accuracy: 0.8895 - val_loss: 4.4135 - val_accuracy: 0.6998 - lr: 5.8622e-04
# Epoch 5/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.2750 - accuracy: 0.9012
# Epoch 5: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 4ms/step - loss: 0.2747 - accuracy: 0.9014 - val_loss: 2.8131 - val_accuracy: 0.6670 - lr: 5.8622e-04
# Epoch 6/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.2681 - accuracy: 0.8988
# Epoch 6: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2680 - accuracy: 0.8990 - val_loss: 5.7093 - val_accuracy: 0.5761 - lr: 5.8622e-04
# Epoch 7/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9017
# Epoch 7: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 4ms/step - loss: 0.2546 - accuracy: 0.9019 - val_loss: 3.2700 - val_accuracy: 0.7241 - lr: 5.8622e-04
# Epoch 8/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.9066
# Epoch 8: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2509 - accuracy: 0.9067 - val_loss: 2.6213 - val_accuracy: 0.6258 - lr: 5.8622e-04
# Epoch 9/200
# 3771/3782 [============================>.] - ETA: 0s - loss: 0.2463 - accuracy: 0.9096
# Epoch 9: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2465 - accuracy: 0.9093 - val_loss: 1.8011 - val_accuracy: 0.6554 - lr: 5.8622e-04
# Epoch 10/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2315 - accuracy: 0.9148
# Epoch 10: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2314 - accuracy: 0.9149 - val_loss: 14.0832 - val_accuracy: 0.6089 - lr: 5.8622e-04
# Epoch 11/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.2300 - accuracy: 0.9174
# Epoch 11: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2297 - accuracy: 0.9175 - val_loss: 11.9480 - val_accuracy: 0.6596 - lr: 5.8622e-04
# Epoch 12/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.2261 - accuracy: 0.9152
# Epoch 12: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2273 - accuracy: 0.9146 - val_loss: 2.7845 - val_accuracy: 0.6279 - lr: 5.8622e-04
# Epoch 13/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2231 - accuracy: 0.9169
# Epoch 13: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2231 - accuracy: 0.9170 - val_loss: 5.5852 - val_accuracy: 0.7156 - lr: 5.8622e-04
# Epoch 14/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.2198 - accuracy: 0.9211
# Epoch 14: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.2198 - accuracy: 0.9212 - val_loss: 10.6421 - val_accuracy: 0.7230 - lr: 5.8622e-04
# Epoch 15/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.2216 - accuracy: 0.9166
# Epoch 15: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2216 - accuracy: 0.9167 - val_loss: 12.4974 - val_accuracy: 0.6395 - lr: 5.8622e-04
# Epoch 16/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.2169 - accuracy: 0.9237
# Epoch 16: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2166 - accuracy: 0.9238 - val_loss: 2.6548 - val_accuracy: 0.7378 - lr: 5.8622e-04
# Epoch 17/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.2368 - accuracy: 0.9210
# Epoch 17: loss did not improve from 0.58902
# 3782/3782 [==============================] - 19s 5ms/step - loss: 0.2370 - accuracy: 0.9207 - val_loss: 29.6481 - val_accuracy: 0.6850 - lr: 5.8622e-04
# Epoch 18/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.2215 - accuracy: 0.9171
# Epoch 18: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2218 - accuracy: 0.9170 - val_loss: 8.2083 - val_accuracy: 0.6755 - lr: 5.8622e-04
# Epoch 19/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.2061 - accuracy: 0.9219
# Epoch 19: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2060 - accuracy: 0.9220 - val_loss: 9.1401 - val_accuracy: 0.7051 - lr: 5.8622e-04
# Epoch 20/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.2077 - accuracy: 0.9246
# Epoch 20: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.2076 - accuracy: 0.9246 - val_loss: 9.7577 - val_accuracy: 0.6543 - lr: 5.8622e-04
# Epoch 21/200
# 3770/3782 [============================>.] - ETA: 0s - loss: 0.2094 - accuracy: 0.9297
# Epoch 21: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2091 - accuracy: 0.9297 - val_loss: 9.5465 - val_accuracy: 0.6607 - lr: 5.8622e-04
# Epoch 22/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9288
# Epoch 22: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1979 - accuracy: 0.9289 - val_loss: 15.3356 - val_accuracy: 0.6596 - lr: 5.8622e-04
# Epoch 23/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9261
# Epoch 23: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1993 - accuracy: 0.9257 - val_loss: 11.7732 - val_accuracy: 0.6416 - lr: 5.8622e-04
# Epoch 24/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9211
# Epoch 24: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2115 - accuracy: 0.9212 - val_loss: 2.6342 - val_accuracy: 0.6860 - lr: 5.8622e-04
# Epoch 25/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1997 - accuracy: 0.9286
# Epoch 25: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1996 - accuracy: 0.9286 - val_loss: 8.3617 - val_accuracy: 0.7104 - lr: 5.8622e-04
# Epoch 26/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9283
# Epoch 26: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1996 - accuracy: 0.9283 - val_loss: 3.4160 - val_accuracy: 0.5973 - lr: 5.8622e-04
# Epoch 27/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1948 - accuracy: 0.9287
# Epoch 27: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1950 - accuracy: 0.9286 - val_loss: 9.2715 - val_accuracy: 0.7051 - lr: 5.8622e-04
# Epoch 28/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.2021 - accuracy: 0.9245
# Epoch 28: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.2022 - accuracy: 0.9244 - val_loss: 8.1515 - val_accuracy: 0.7262 - lr: 5.8622e-04
# Epoch 29/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9276
# Epoch 29: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1990 - accuracy: 0.9276 - val_loss: 21.0179 - val_accuracy: 0.7156 - lr: 5.8622e-04
# Epoch 30/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1913 - accuracy: 0.9319
# Epoch 30: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1914 - accuracy: 0.9315 - val_loss: 14.4533 - val_accuracy: 0.7125 - lr: 5.8622e-04
# Epoch 31/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9352
# Epoch 31: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1938 - accuracy: 0.9352 - val_loss: 3.5179 - val_accuracy: 0.7812 - lr: 5.8622e-04
# Epoch 32/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1834 - accuracy: 0.9315
# Epoch 32: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1834 - accuracy: 0.9315 - val_loss: 8.7301 - val_accuracy: 0.7104 - lr: 5.8622e-04
# Epoch 33/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1904 - accuracy: 0.9285
# Epoch 33: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1904 - accuracy: 0.9283 - val_loss: 18.3812 - val_accuracy: 0.6490 - lr: 5.8622e-04
# Epoch 34/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1931 - accuracy: 0.9312
# Epoch 34: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1929 - accuracy: 0.9313 - val_loss: 4.6144 - val_accuracy: 0.7146 - lr: 5.8622e-04
# Epoch 35/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9333
# Epoch 35: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.1937 - accuracy: 0.9331 - val_loss: 16.5498 - val_accuracy: 0.6860 - lr: 5.8622e-04
# Epoch 36/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9307
# Epoch 36: loss did not improve from 0.58902
# 3782/3782 [==============================] - 19s 5ms/step - loss: 0.1928 - accuracy: 0.9307 - val_loss: 13.1269 - val_accuracy: 0.7135 - lr: 5.8622e-04
# Epoch 37/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9311
# Epoch 37: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1817 - accuracy: 0.9313 - val_loss: 4.6841 - val_accuracy: 0.7421 - lr: 5.8622e-04
# Epoch 38/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1887 - accuracy: 0.9331
# Epoch 38: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1886 - accuracy: 0.9331 - val_loss: 2.5897 - val_accuracy: 0.6311 - lr: 5.8622e-04
# Epoch 39/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1825 - accuracy: 0.9335
# Epoch 39: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1823 - accuracy: 0.9336 - val_loss: 8.0727 - val_accuracy: 0.7326 - lr: 5.8622e-04
# Epoch 40/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1844 - accuracy: 0.9335
# Epoch 40: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1844 - accuracy: 0.9336 - val_loss: 9.6561 - val_accuracy: 0.7188 - lr: 5.8622e-04
# Epoch 41/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1762 - accuracy: 0.9338
# Epoch 41: loss did not improve from 0.58902
# 3782/3782 [==============================] - 23s 6ms/step - loss: 0.1760 - accuracy: 0.9339 - val_loss: 13.5115 - val_accuracy: 0.7304 - lr: 5.8622e-04
# Epoch 42/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1873 - accuracy: 0.9328
# Epoch 42: loss did not improve from 0.58902
# 3782/3782 [==============================] - 22s 6ms/step - loss: 0.1872 - accuracy: 0.9328 - val_loss: 11.1381 - val_accuracy: 0.6924 - lr: 5.8622e-04
# Epoch 43/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1777 - accuracy: 0.9394
# Epoch 43: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1776 - accuracy: 0.9395 - val_loss: 11.7706 - val_accuracy: 0.6829 - lr: 5.8622e-04
# Epoch 44/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1853 - accuracy: 0.9362
# Epoch 44: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1853 - accuracy: 0.9363 - val_loss: 16.3405 - val_accuracy: 0.6987 - lr: 5.8622e-04
# Epoch 45/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1785 - accuracy: 0.9327
# Epoch 45: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1783 - accuracy: 0.9328 - val_loss: 15.0206 - val_accuracy: 0.6797 - lr: 5.8622e-04
# Epoch 46/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1825 - accuracy: 0.9343
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00011724400101229549.
#
# Epoch 46: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1823 - accuracy: 0.9342 - val_loss: 10.2174 - val_accuracy: 0.7357 - lr: 5.8622e-04
# Epoch 47/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1508 - accuracy: 0.9468
# Epoch 47: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1508 - accuracy: 0.9469 - val_loss: 20.7648 - val_accuracy: 0.6797 - lr: 1.1724e-04
# Epoch 48/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1431 - accuracy: 0.9542
# Epoch 48: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1431 - accuracy: 0.9543 - val_loss: 19.3131 - val_accuracy: 0.7220 - lr: 1.1724e-04
# Epoch 49/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9499
# Epoch 49: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1371 - accuracy: 0.9500 - val_loss: 10.8242 - val_accuracy: 0.7431 - lr: 1.1724e-04
# Epoch 50/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9544
# Epoch 50: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1328 - accuracy: 0.9545 - val_loss: 19.3659 - val_accuracy: 0.6702 - lr: 1.1724e-04
# Epoch 51/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9533
# Epoch 51: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1345 - accuracy: 0.9535 - val_loss: 23.2403 - val_accuracy: 0.7262 - lr: 1.1724e-04
# Epoch 52/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9521
# Epoch 52: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1341 - accuracy: 0.9521 - val_loss: 20.3498 - val_accuracy: 0.7114 - lr: 1.1724e-04
# Epoch 53/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1304 - accuracy: 0.9531
# Epoch 53: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1305 - accuracy: 0.9529 - val_loss: 27.0697 - val_accuracy: 0.7230 - lr: 1.1724e-04
# Epoch 54/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.9542
# Epoch 54: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1264 - accuracy: 0.9543 - val_loss: 32.1079 - val_accuracy: 0.7019 - lr: 1.1724e-04
# Epoch 55/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9526
# Epoch 55: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1306 - accuracy: 0.9527 - val_loss: 19.6144 - val_accuracy: 0.7844 - lr: 1.1724e-04
# Epoch 56/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1268 - accuracy: 0.9571
# Epoch 56: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1271 - accuracy: 0.9569 - val_loss: 29.0760 - val_accuracy: 0.7378 - lr: 1.1724e-04
# Epoch 57/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1254 - accuracy: 0.9539
# Epoch 57: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1254 - accuracy: 0.9540 - val_loss: 32.1472 - val_accuracy: 0.7537 - lr: 1.1724e-04
# Epoch 58/200
# 3773/3782 [============================>.] - ETA: 0s - loss: 0.1272 - accuracy: 0.9539
# Epoch 58: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1270 - accuracy: 0.9540 - val_loss: 27.1239 - val_accuracy: 0.7505 - lr: 1.1724e-04
# Epoch 59/200
# 3773/3782 [============================>.] - ETA: 0s - loss: 0.1249 - accuracy: 0.9563
# Epoch 59: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 6ms/step - loss: 0.1247 - accuracy: 0.9564 - val_loss: 30.4074 - val_accuracy: 0.7283 - lr: 1.1724e-04
# Epoch 60/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.9566
# Epoch 60: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1242 - accuracy: 0.9566 - val_loss: 21.9282 - val_accuracy: 0.7125 - lr: 1.1724e-04
# Epoch 61/200
# 3773/3782 [============================>.] - ETA: 0s - loss: 0.1198 - accuracy: 0.9597
# Epoch 61: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1214 - accuracy: 0.9595 - val_loss: 25.7506 - val_accuracy: 0.7241 - lr: 1.1724e-04
# Epoch 62/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1241 - accuracy: 0.9568
# Epoch 62: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1239 - accuracy: 0.9569 - val_loss: 44.5235 - val_accuracy: 0.6512 - lr: 1.1724e-04
# Epoch 63/200
# 3773/3782 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9571
# Epoch 63: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1205 - accuracy: 0.9572 - val_loss: 27.3195 - val_accuracy: 0.7093 - lr: 1.1724e-04
# Epoch 64/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9563
# Epoch 64: loss did not improve from 0.58902
# 3782/3782 [==============================] - 22s 6ms/step - loss: 0.1213 - accuracy: 0.9564 - val_loss: 27.9654 - val_accuracy: 0.7051 - lr: 1.1724e-04
# Epoch 65/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9587
# Epoch 65: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1214 - accuracy: 0.9588 - val_loss: 25.6571 - val_accuracy: 0.7104 - lr: 1.1724e-04
# Epoch 66/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9556
# Epoch 66: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1205 - accuracy: 0.9556 - val_loss: 34.6592 - val_accuracy: 0.7220 - lr: 1.1724e-04
# Epoch 67/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1233 - accuracy: 0.9563
# Epoch 67: loss did not improve from 0.58902
# 3782/3782 [==============================] - 23s 6ms/step - loss: 0.1233 - accuracy: 0.9564 - val_loss: 28.8107 - val_accuracy: 0.7199 - lr: 1.1724e-04
# Epoch 68/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1170 - accuracy: 0.9603
# Epoch 68: loss did not improve from 0.58902
# 3782/3782 [==============================] - 29s 8ms/step - loss: 0.1170 - accuracy: 0.9603 - val_loss: 34.4079 - val_accuracy: 0.7421 - lr: 1.1724e-04
# Epoch 69/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9576
# Epoch 69: loss did not improve from 0.58902
# 3782/3782 [==============================] - 23s 6ms/step - loss: 0.1181 - accuracy: 0.9577 - val_loss: 35.0069 - val_accuracy: 0.7421 - lr: 1.1724e-04
# Epoch 70/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9593
# Epoch 70: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1207 - accuracy: 0.9593 - val_loss: 37.8233 - val_accuracy: 0.6734 - lr: 1.1724e-04
# Epoch 71/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1217 - accuracy: 0.9579
# Epoch 71: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1216 - accuracy: 0.9580 - val_loss: 28.1522 - val_accuracy: 0.7537 - lr: 1.1724e-04
# Epoch 72/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9622
# Epoch 72: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1148 - accuracy: 0.9619 - val_loss: 25.7533 - val_accuracy: 0.7516 - lr: 1.1724e-04
# Epoch 73/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9572
# Epoch 73: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1134 - accuracy: 0.9572 - val_loss: 41.7993 - val_accuracy: 0.6797 - lr: 1.1724e-04
# Epoch 74/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9587
# Epoch 74: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1173 - accuracy: 0.9588 - val_loss: 34.5542 - val_accuracy: 0.7230 - lr: 1.1724e-04
# Epoch 75/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9590
# Epoch 75: loss did not improve from 0.58902
# 3782/3782 [==============================] - 22s 6ms/step - loss: 0.1165 - accuracy: 0.9590 - val_loss: 62.1429 - val_accuracy: 0.6512 - lr: 1.1724e-04
# Epoch 76/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9584
# Epoch 76: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1168 - accuracy: 0.9585 - val_loss: 41.6194 - val_accuracy: 0.7156 - lr: 1.1724e-04
# Epoch 77/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9597
# Epoch 77: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1144 - accuracy: 0.9598 - val_loss: 49.2759 - val_accuracy: 0.6427 - lr: 1.1724e-04
# Epoch 78/200
# 3772/3782 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9592
# Epoch 78: ReduceLROnPlateau reducing learning rate to 2.3448800493497402e-05.
#
# Epoch 78: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1146 - accuracy: 0.9590 - val_loss: 27.8570 - val_accuracy: 0.7431 - lr: 1.1724e-04
# Epoch 79/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9653
# Epoch 79: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 5ms/step - loss: 0.1057 - accuracy: 0.9654 - val_loss: 45.3337 - val_accuracy: 0.6649 - lr: 2.3449e-05
# Epoch 80/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9661
# Epoch 80: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.1035 - accuracy: 0.9659 - val_loss: 40.6245 - val_accuracy: 0.7125 - lr: 2.3449e-05
# Epoch 81/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9651
# Epoch 81: loss did not improve from 0.58902
# 3782/3782 [==============================] - 21s 6ms/step - loss: 0.1026 - accuracy: 0.9651 - val_loss: 29.2471 - val_accuracy: 0.7960 - lr: 2.3449e-05
# Epoch 82/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1018 - accuracy: 0.9648
# Epoch 82: loss did not improve from 0.58902
# 3782/3782 [==============================] - 27s 7ms/step - loss: 0.1018 - accuracy: 0.9648 - val_loss: 35.4523 - val_accuracy: 0.7252 - lr: 2.3449e-05
# Epoch 83/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9637
# Epoch 83: loss did not improve from 0.58902
# 3782/3782 [==============================] - 29s 8ms/step - loss: 0.1028 - accuracy: 0.9638 - val_loss: 30.4228 - val_accuracy: 0.7770 - lr: 2.3449e-05
# Epoch 84/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9672
# Epoch 84: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0995 - accuracy: 0.9672 - val_loss: 42.9287 - val_accuracy: 0.7262 - lr: 2.3449e-05
# Epoch 85/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.0991 - accuracy: 0.9672
# Epoch 85: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0991 - accuracy: 0.9672 - val_loss: 48.8136 - val_accuracy: 0.6924 - lr: 2.3449e-05
# Epoch 86/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1007 - accuracy: 0.9666
# Epoch 86: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.1006 - accuracy: 0.9667 - val_loss: 49.9647 - val_accuracy: 0.6987 - lr: 2.3449e-05
# Epoch 87/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1036 - accuracy: 0.9632
# Epoch 87: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.1035 - accuracy: 0.9632 - val_loss: 43.8290 - val_accuracy: 0.7030 - lr: 2.3449e-05
# Epoch 88/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9672
# Epoch 88: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0985 - accuracy: 0.9672 - val_loss: 44.3465 - val_accuracy: 0.6956 - lr: 2.3449e-05
# Epoch 89/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0974 - accuracy: 0.9666
# Epoch 89: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.0973 - accuracy: 0.9667 - val_loss: 43.6491 - val_accuracy: 0.7178 - lr: 2.3449e-05
# Epoch 90/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9661
# Epoch 90: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0995 - accuracy: 0.9662 - val_loss: 48.6109 - val_accuracy: 0.7378 - lr: 2.3449e-05
# Epoch 91/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1014 - accuracy: 0.9653
# Epoch 91: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.1014 - accuracy: 0.9654 - val_loss: 33.7518 - val_accuracy: 0.7812 - lr: 2.3449e-05
# Epoch 92/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0993 - accuracy: 0.9677
# Epoch 92: loss did not improve from 0.58902
# 3782/3782 [==============================] - 34s 9ms/step - loss: 0.0993 - accuracy: 0.9677 - val_loss: 58.0898 - val_accuracy: 0.6649 - lr: 2.3449e-05
# Epoch 93/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9663
# Epoch 93: loss did not improve from 0.58902
# 3782/3782 [==============================] - 29s 8ms/step - loss: 0.0977 - accuracy: 0.9662 - val_loss: 43.4821 - val_accuracy: 0.7632 - lr: 2.3449e-05
# Epoch 94/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9675
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.6897599531803285e-06.
#
# Epoch 94: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0999 - accuracy: 0.9675 - val_loss: 59.4176 - val_accuracy: 0.6776 - lr: 2.3449e-05
# Epoch 95/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0959 - accuracy: 0.9691
# Epoch 95: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0959 - accuracy: 0.9691 - val_loss: 61.7084 - val_accuracy: 0.6776 - lr: 4.6898e-06
# Epoch 96/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9674
# Epoch 96: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.0968 - accuracy: 0.9675 - val_loss: 51.6472 - val_accuracy: 0.7072 - lr: 4.6898e-06
# Epoch 97/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0977 - accuracy: 0.9688
# Epoch 97: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0988 - accuracy: 0.9685 - val_loss: 45.0226 - val_accuracy: 0.7833 - lr: 4.6898e-06
# Epoch 98/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9691
# Epoch 98: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0961 - accuracy: 0.9691 - val_loss: 46.7441 - val_accuracy: 0.7770 - lr: 4.6898e-06
# Epoch 99/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.0970 - accuracy: 0.9688
# Epoch 99: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.0969 - accuracy: 0.9688 - val_loss: 45.2915 - val_accuracy: 0.7865 - lr: 4.6898e-06
# Epoch 100/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.0974 - accuracy: 0.9695
# Epoch 100: ReduceLROnPlateau reducing learning rate to 9.379519724461717e-07.
#
# Epoch 100: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.0978 - accuracy: 0.9691 - val_loss: 60.1702 - val_accuracy: 0.6882 - lr: 4.6898e-06
# Epoch 101/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9696
# Epoch 101: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.0955 - accuracy: 0.9696 - val_loss: 52.9906 - val_accuracy: 0.7146 - lr: 9.3795e-07
# Epoch 102/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9691
# Epoch 102: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0967 - accuracy: 0.9691 - val_loss: 51.7823 - val_accuracy: 0.7653 - lr: 9.3795e-07
# Epoch 103/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0954 - accuracy: 0.9688
# Epoch 103: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0956 - accuracy: 0.9685 - val_loss: 50.5947 - val_accuracy: 0.7505 - lr: 9.3795e-07
# Epoch 104/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9667
# Epoch 104: loss did not improve from 0.58902
# 3782/3782 [==============================] - 26s 7ms/step - loss: 0.0962 - accuracy: 0.9667 - val_loss: 52.9695 - val_accuracy: 0.7040 - lr: 9.3795e-07
# Epoch 105/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9667
# Epoch 105: loss did not improve from 0.58902
# 3782/3782 [==============================] - 25s 7ms/step - loss: 0.0990 - accuracy: 0.9667 - val_loss: 50.8143 - val_accuracy: 0.7442 - lr: 9.3795e-07
# Epoch 106/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9672
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1.8759039903670783e-07.
#
# Epoch 106: loss did not improve from 0.58902
# 3782/3782 [==============================] - 24s 6ms/step - loss: 0.0967 - accuracy: 0.9672 - val_loss: 48.6589 - val_accuracy: 0.7738 - lr: 9.3795e-07
# Epoch 107/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9672
# Epoch 107: loss did not improve from 0.58902
# 3782/3782 [==============================] - 20s 5ms/step - loss: 0.0975 - accuracy: 0.9669 - val_loss: 50.8866 - val_accuracy: 0.7495 - lr: 1.8759e-07
# Epoch 108/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0958 - accuracy: 0.9688
# Epoch 108: loss did not improve from 0.58902
# 3782/3782 [==============================] - 16s 4ms/step - loss: 0.0958 - accuracy: 0.9688 - val_loss: 48.9040 - val_accuracy: 0.7516 - lr: 1.8759e-07
# Epoch 109/200
# 3773/3782 [============================>.] - ETA: 0s - loss: 0.0974 - accuracy: 0.9685
# Epoch 109: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 4ms/step - loss: 0.0972 - accuracy: 0.9685 - val_loss: 53.3132 - val_accuracy: 0.7674 - lr: 1.8759e-07
# Epoch 110/200
# 3771/3782 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9700
# Epoch 110: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 4ms/step - loss: 0.0953 - accuracy: 0.9701 - val_loss: 48.4063 - val_accuracy: 0.7526 - lr: 1.8759e-07
# Epoch 111/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9688
# Epoch 111: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.0945 - accuracy: 0.9685 - val_loss: 71.8229 - val_accuracy: 0.6755 - lr: 1.8759e-07
# Epoch 112/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9709
# Epoch 112: loss did not improve from 0.58902
# 3782/3782 [==============================] - 17s 5ms/step - loss: 0.0933 - accuracy: 0.9709 - val_loss: 54.3728 - val_accuracy: 0.7104 - lr: 1.8759e-07
# Epoch 113/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9693
# Epoch 113: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0951 - accuracy: 0.9691 - val_loss: 46.7392 - val_accuracy: 0.7674 - lr: 1.8759e-07
# Epoch 114/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0974 - accuracy: 0.9691
# Epoch 114: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0974 - accuracy: 0.9691 - val_loss: 52.8675 - val_accuracy: 0.7706 - lr: 1.8759e-07
# Epoch 115/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.0957 - accuracy: 0.9690
# Epoch 115: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0956 - accuracy: 0.9691 - val_loss: 65.3909 - val_accuracy: 0.6850 - lr: 1.8759e-07
# Epoch 116/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.0972 - accuracy: 0.9685
# Epoch 116: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0971 - accuracy: 0.9685 - val_loss: 52.1897 - val_accuracy: 0.7833 - lr: 1.8759e-07
# Epoch 117/200
# 3771/3782 [============================>.] - ETA: 0s - loss: 0.0941 - accuracy: 0.9695
# Epoch 117: ReduceLROnPlateau reducing learning rate to 3.7518080375775756e-08.
#
# Epoch 117: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0939 - accuracy: 0.9696 - val_loss: 55.6966 - val_accuracy: 0.7008 - lr: 1.8759e-07
# Epoch 118/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.0957 - accuracy: 0.9669
# Epoch 118: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0956 - accuracy: 0.9669 - val_loss: 65.4205 - val_accuracy: 0.6850 - lr: 3.7518e-08
# Epoch 119/200
# 3771/3782 [============================>.] - ETA: 0s - loss: 0.0935 - accuracy: 0.9690
# Epoch 119: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0933 - accuracy: 0.9691 - val_loss: 49.6221 - val_accuracy: 0.7516 - lr: 3.7518e-08
# Epoch 120/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9674
# Epoch 120: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0969 - accuracy: 0.9675 - val_loss: 70.5822 - val_accuracy: 0.6638 - lr: 3.7518e-08
# Epoch 121/200
# 3773/3782 [============================>.] - ETA: 0s - loss: 0.0950 - accuracy: 0.9690
# Epoch 121: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0948 - accuracy: 0.9691 - val_loss: 62.2169 - val_accuracy: 0.6871 - lr: 3.7518e-08
# Epoch 122/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.0958 - accuracy: 0.9680
# Epoch 122: ReduceLROnPlateau reducing learning rate to 7.503616217263698e-09.
#
# Epoch 122: loss did not improve from 0.58902
# 3782/3782 [==============================] - 18s 5ms/step - loss: 0.0957 - accuracy: 0.9680 - val_loss: 47.4564 - val_accuracy: 0.7463 - lr: 3.7518e-08
# Epoch 122: early stopping

# %%
model.evaluate(X_test, y_test)
# Out:
# 148/148 [==============================] - 1s 3ms/step - loss: 86.9300 - accuracy: 0.6599
# [86.92997741699219, 0.6598984599113464]

# %%
predictions = model.predict(X_test).astype("int").flatten()
# Out:
# 148/148 [==============================] - 1s 3ms/step

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predictions, normalize='true', values_format='.0%')
plt.show()

# %%
print(f'Recall: {recall_score(y_test, predictions)}')
print(f'Precision: {precision_score(y_test, predictions)}')
# Out:
# Recall: 0.335727969348659
# Precision: 0.5158204562178073

# %%
model.save(f'{modelpath}/cnnTradingCSNA.h5')
