# %% [markdown]
# # MBA em Ciência de Dados e Inteligência Artificial - FIAP - 2024
# # Projeto Integrado - Deep Learning

# %% [markdown]
# ## Descrição do Projeto:
#
# A QuantumFinance está desejando construir um fundo de ações baseado em modelos de Deep Learning. A ideia é desenvolver um modelo que tenha como saída a compra ou venda de uma determinada ação baseado na movimentação do mercado nos últimos 15 dias.

# %% [markdown]
# ## O Desafio:
# A empresa deseja um modelo de Deep Learning que seja um ‘perseguidor de tendencia’, ou seja, se o papel sobe o modelo deve comprar, se o papel desce o
# modelo deve vender. Para isso a QuantumFinance contratou economistas que fizerem a rotulagem dos dados baseado no valor de fechamento dos ativos. Inicialmente foi feita uma suavização dos preços de fechamento, e por se tratar de um assunto sigiloso, não foi informada a técnica de suavização utilizada. O próximo passo foi realizar a rotulagem dia a dia, para verificar qual devemos comprar e qual devemos vender.

# %% [markdown]
# Para esse notebook, contemplo uma arquitetura simples de redes utilizando CNN + LSTM. Essa arquitetura foi baseada em artigos para finalidade de estudo, disponíveis através do arquivo README.md, utilizando a ação VALE3 - Vale do Rio Doce para ajustes. Como bônus, abordo outras 3 ações (BBAS3 - Banco do Brasil, CSNA3 - Companhia Siderúrgica Nacional, PETR4 - Petrobras) para avaliar como a rede se comporta com outras ações.

# %%
from pathlib import Path 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.graph_objects as go

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import ConfusionMatrixDisplay, recall_score, precision_score

from keras.models import Sequential
from keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, LSTM, Bidirectional
from keras.regularizers import l1_l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras_tuner.tuners import Hyperband

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend

# %%
datapath = Path('../data')
modelpath = Path('../model')

# %%
data = pd.read_csv(f'{datapath}/csv/CSNA3train.csv')
data = data[['Date', 'Smoothed_Close', 'Label']]
data.head()
# Out:
#          Date  Smoothed_Close  Label
# 0  2000-01-24        1.588954     -1
# 1  2000-01-26        1.569864     -1
# 2  2000-01-27        1.550466     -1
# 3  2000-01-28        1.531815     -1
# 4  2000-01-31        1.511619     -1

# %%
data['Label'].value_counts()
# Out:
# -1    2655
#  1    2088
# Name: Label, dtype: int64

# %%
class LabelTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        X = X.copy()
        X.loc[X['Label'] == -1, 'Label'] = 0
        return X

# %%
data_test = pd.read_csv(f'{datapath}/csv/CSNA3test.csv')
data_test = data_test[['Smoothed_Close', 'Label']]

# %%
label_transformer = LabelTransformer()
data = label_transformer.fit_transform(data)
data_test = label_transformer.transform(data_test)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4743 entries, 0 to 4742
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            4743 non-null   object
#  1   Smoothed_Close  4743 non-null   float64
#  2   Label           4743 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 111.3+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Year'] = data['Date'].dt.year

# %%
fig = go.Figure()

for year in data['Year'].unique():
    year_data = data[data['Year'] == year]
    fig.add_trace(go.Scatter(x=year_data['Date'], y=year_data['Smoothed_Close'],
                             mode='lines', name=str(year)))

for label, name, color in zip([0, 1], ['Venda', 'Compra'], ['red', 'green']):
    label_data = data[data['Label'] == label]
    fig.add_trace(go.Scatter(x=label_data['Date'], y=label_data['Smoothed_Close'],
                             mode='markers', name=name, marker_color=color))

fig.update_layout(title='CSNA3 - Companhia Siderúrgica Nacional',
                  xaxis_title='Anos',
                  yaxis_title='Preços de Fechamento',
                  legend_title='Legenda')

fig.show()

# %%
data.drop(['Date', 'Year'], axis=1, inplace=True)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close = scaler.fit_transform(data[['Smoothed_Close']])
scaled_close_test = scaler.transform(data_test[['Smoothed_Close']])

# %%
data['Scaled_Close'] = scaled_close.flatten()
data_test['Scaled_Close'] = scaled_close_test.flatten()

# %%
def create_window(data, label, window_size=15):
    X, y = [], []
    
    for i in range(len(data) - window_size):
        window = data[i:(i + window_size)]
        cumulative_avg = np.mean(window)
        window = np.append(window, cumulative_avg)
        window = np.expand_dims(window, axis=-1)
        X.append(window)
        y.append(label[i + window_size])

    return np.array(X), np.array(y)

# %%
X_train, y_train = create_window(data=data['Scaled_Close'], label=data['Label'], window_size=15)
X_test, y_test = create_window(data=data['Scaled_Close'], label=data['Label'], window_size=15)

# %%
def rede_cnnTrading(hp):
    model = Sequential()
    model.add(Conv1D(
        filters=hp.Int('filters_1', min_value=32, max_value=64, step=32),
        kernel_size=hp.Choice('kernel_size_1', values=[2, 3]),
        activation=hp.Choice('activ1', values=['relu', 'tanh', 'elu']),
        padding='same', kernel_initializer='he_uniform', input_shape=(16, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=hp.Choice('pool1', values=[1, 2])))
    # model.add(Conv1D(
    #     filters=hp.Int('filters_2', min_value=32, max_value=128, step=32),
    #     kernel_size=hp.Choice('kernel_size_2', values=[2, 3]),
    #     activation=hp.Choice('activ2', values=['relu', 'tanh', 'elu']),
    #     padding='same', kernel_initializer='he_uniform'))
    # model.add(BatchNormalization())
    # model.add(MaxPooling1D(pool_size=hp.Choice('poo2', values=[1, 2])))
    # model.add(Conv1D(
    #     filters=hp.Int('filters_3', min_value=32, max_value=64, step=32),
    #     kernel_size=hp.Choice('kernel_size_3', values=[2, 3]),
    #     activation=hp.Choice('activ3', values=['relu', 'tanh', 'elu']),
    #     padding='same', kernel_initializer='he_uniform'))
    # model.add(MaxPooling1D(pool_size=hp.Choice('poo3', values=[1, 2])))
    # model.add(Bidirectional(LSTM(
    #     units=hp.Int('lstm_units1', min_value=50, max_value=100, step=50),
    #     activation=hp.Choice('actv3', values=['relu', 'tanh', 'elu']), return_sequences=True, kernel_initializer='he_uniform')))
    # model.add(Dropout(hp.Float('dropout_rate1', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(Bidirectional(LSTM(
        units=hp.Int('lstm_units2', min_value=50, max_value=100, step=50),
        activation=hp.Choice('actv4', values=['relu', 'tanh', 'elu']), kernel_initializer='he_uniform')))
    # model.add(Dropout(hp.Float('dropout_rate2', min_value=0.0, max_value=0.5, step=0.1)))
    # model.add(TimeDistributed(Dense(units=1, activation=hp.Choice('activ2', values=['relu', 'tanh']), kernel_initializer='he_uniform')))
    model.add(Dropout(hp.Float('dropout_rate3', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(Dense(units=1, activation='sigmoid', kernel_initializer='he_uniform',
                                    kernel_regularizer=l1_l2(l1=hp.Float('l1', min_value=0.0, max_value=0.05, step=0.01), l2=hp.Float('l1', min_value=0.0, max_value=0.05, step=0.01))))
    model.compile(optimizer=Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-3, sampling='LOG')),
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = Hyperband(
    rede_cnnTrading,
    objective='val_accuracy',
    max_epochs=100,
    directory=f'{modelpath}',
    project_name='hparam_tuning')
# Out:
# Reloading Tuner from ..\model\hparam_tuning\tuner0.json

# %%
es = EarlyStopping(monitor='loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, verbose=1)
mcp = ModelCheckpoint(filepath=f'{modelpath}/pesosCSNA.h5', monitor='loss', save_best_only=True, verbose=1, mode='max')
callbacks = [es, rlr, mcp]

# %%
train_size = int(len(X_train) * 0.8)
X_train_split, X_val_split = X_train[:train_size], X_train[train_size:]
y_train_split, y_val_split = y_train[:train_size], y_train[train_size:]

# %%
tuner.search(X_train, y_train, validation_data=(X_val_split, y_val_split), epochs=100, callbacks=[es, rlr, mcp], batch_size=1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='elu', padding='same', kernel_initializer='he_uniform', input_shape=(16, 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(units=50, activation='relu', kernel_initializer='he_uniform')))
model.add(Dropout(0.3))
model.add(Dense(units=1, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l1_l2(l1=0.02, l2=0.02)))
model.compile(optimizer=Adam(learning_rate=0.00058622), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TradingClassifierCSNA = model.fit(X_train_split, y_train_split, epochs=200, batch_size=1, validation_data=(X_val_split, y_val_split), callbacks=[es, rlr, mcp])
# Out:
# Epoch 1/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.4981 - accuracy: 0.8231
# Epoch 1: loss improved from -inf to 0.49794, saving model to ..\model\pesosCSNA.h5
# 3782/3782 [==============================] - 71s 13ms/step - loss: 0.4979 - accuracy: 0.8231 - val_loss: 7.1286 - val_accuracy: 0.6575 - lr: 5.8622e-04
# Epoch 2/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.3184 - accuracy: 0.8841
# Epoch 2: loss did not improve from 0.49794
# 3782/3782 [==============================] - 50s 13ms/step - loss: 0.3183 - accuracy: 0.8839 - val_loss: 10.2047 - val_accuracy: 0.6321 - lr: 5.8622e-04
# Epoch 3/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.9004
# Epoch 3: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.2819 - accuracy: 0.9006 - val_loss: 11.6940 - val_accuracy: 0.6734 - lr: 5.8622e-04
# Epoch 4/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.2559 - accuracy: 0.9071
# Epoch 4: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2559 - accuracy: 0.9072 - val_loss: 9.3899 - val_accuracy: 0.6459 - lr: 5.8622e-04
# Epoch 5/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.2420 - accuracy: 0.9116
# Epoch 5: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.2419 - accuracy: 0.9117 - val_loss: 12.1218 - val_accuracy: 0.5433 - lr: 5.8622e-04
# Epoch 6/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2286 - accuracy: 0.9167
# Epoch 6: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2294 - accuracy: 0.9164 - val_loss: 13.7816 - val_accuracy: 0.6797 - lr: 5.8622e-04
# Epoch 7/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.2244 - accuracy: 0.9196
# Epoch 7: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2243 - accuracy: 0.9196 - val_loss: 7.1985 - val_accuracy: 0.6089 - lr: 5.8622e-04
# Epoch 8/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.2200 - accuracy: 0.9206
# Epoch 8: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2204 - accuracy: 0.9201 - val_loss: 12.5186 - val_accuracy: 0.5867 - lr: 5.8622e-04
# Epoch 9/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2139 - accuracy: 0.9246
# Epoch 9: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2139 - accuracy: 0.9246 - val_loss: 19.9651 - val_accuracy: 0.6427 - lr: 5.8622e-04
# Epoch 10/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2132 - accuracy: 0.9214
# Epoch 10: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.2132 - accuracy: 0.9215 - val_loss: 8.7120 - val_accuracy: 0.5909 - lr: 5.8622e-04
# Epoch 11/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.2298 - accuracy: 0.9227
# Epoch 11: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2296 - accuracy: 0.9228 - val_loss: 17.2793 - val_accuracy: 0.5307 - lr: 5.8622e-04
# Epoch 12/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.9243
# Epoch 12: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.2154 - accuracy: 0.9244 - val_loss: 8.1371 - val_accuracy: 0.5592 - lr: 5.8622e-04
# Epoch 13/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.2015 - accuracy: 0.9267
# Epoch 13: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.2013 - accuracy: 0.9268 - val_loss: 7.9447 - val_accuracy: 0.6300 - lr: 5.8622e-04
# Epoch 14/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1943 - accuracy: 0.9291
# Epoch 14: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1953 - accuracy: 0.9286 - val_loss: 24.9142 - val_accuracy: 0.6533 - lr: 5.8622e-04
# Epoch 15/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.2132 - accuracy: 0.9285
# Epoch 15: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.2130 - accuracy: 0.9286 - val_loss: 3.5336 - val_accuracy: 0.7040 - lr: 5.8622e-04
# Epoch 16/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9315
# Epoch 16: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1987 - accuracy: 0.9315 - val_loss: 8.0579 - val_accuracy: 0.5740 - lr: 5.8622e-04
# Epoch 17/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1936 - accuracy: 0.9320
# Epoch 17: loss did not improve from 0.49794
# 3782/3782 [==============================] - 44s 12ms/step - loss: 0.1934 - accuracy: 0.9320 - val_loss: 5.3097 - val_accuracy: 0.6268 - lr: 5.8622e-04
# Epoch 18/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1925 - accuracy: 0.9278
# Epoch 18: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1925 - accuracy: 0.9278 - val_loss: 24.8622 - val_accuracy: 0.6660 - lr: 5.8622e-04
# Epoch 19/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.2008 - accuracy: 0.9299
# Epoch 19: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.2007 - accuracy: 0.9299 - val_loss: 10.2203 - val_accuracy: 0.5708 - lr: 5.8622e-04
# Epoch 20/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1915 - accuracy: 0.9315
# Epoch 20: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1915 - accuracy: 0.9315 - val_loss: 4.5083 - val_accuracy: 0.5994 - lr: 5.8622e-04
# Epoch 21/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1845 - accuracy: 0.9330
# Epoch 21: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 13ms/step - loss: 0.1844 - accuracy: 0.9331 - val_loss: 7.7146 - val_accuracy: 0.5444 - lr: 5.8622e-04
# Epoch 22/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1822 - accuracy: 0.9346
# Epoch 22: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1825 - accuracy: 0.9344 - val_loss: 11.0650 - val_accuracy: 0.5592 - lr: 5.8622e-04
# Epoch 23/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1903 - accuracy: 0.9323
# Epoch 23: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1903 - accuracy: 0.9323 - val_loss: 11.2895 - val_accuracy: 0.5222 - lr: 5.8622e-04
# Epoch 24/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1778 - accuracy: 0.9356
# Epoch 24: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1776 - accuracy: 0.9357 - val_loss: 6.8566 - val_accuracy: 0.5846 - lr: 5.8622e-04
# Epoch 25/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1785 - accuracy: 0.9347
# Epoch 25: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1784 - accuracy: 0.9347 - val_loss: 11.0498 - val_accuracy: 0.6068 - lr: 5.8622e-04
# Epoch 26/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1778 - accuracy: 0.9336
# Epoch 26: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1779 - accuracy: 0.9336 - val_loss: 134.0583 - val_accuracy: 0.6205 - lr: 5.8622e-04
# Epoch 27/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1810 - accuracy: 0.9360
# Epoch 27: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1810 - accuracy: 0.9360 - val_loss: 141.5034 - val_accuracy: 0.5476 - lr: 5.8622e-04
# Epoch 28/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1948 - accuracy: 0.9352
# Epoch 28: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1948 - accuracy: 0.9352 - val_loss: 83.8746 - val_accuracy: 0.5877 - lr: 5.8622e-04
# Epoch 29/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1632 - accuracy: 0.9413
# Epoch 29: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 13ms/step - loss: 0.1631 - accuracy: 0.9413 - val_loss: 49.6637 - val_accuracy: 0.6321 - lr: 5.8622e-04
# Epoch 30/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1715 - accuracy: 0.9375
# Epoch 30: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1715 - accuracy: 0.9376 - val_loss: 142.0428 - val_accuracy: 0.6078 - lr: 5.8622e-04
# Epoch 31/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.9379
# Epoch 31: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1765 - accuracy: 0.9379 - val_loss: 133.8254 - val_accuracy: 0.6797 - lr: 5.8622e-04
# Epoch 32/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1809 - accuracy: 0.9355
# Epoch 32: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1809 - accuracy: 0.9355 - val_loss: 138.2660 - val_accuracy: 0.6797 - lr: 5.8622e-04
# Epoch 33/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1788 - accuracy: 0.9391
# Epoch 33: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1787 - accuracy: 0.9392 - val_loss: 112.7003 - val_accuracy: 0.6564 - lr: 5.8622e-04
# Epoch 34/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9371
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00011724400101229549.
#
# Epoch 34: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1740 - accuracy: 0.9371 - val_loss: 59.9480 - val_accuracy: 0.6173 - lr: 5.8622e-04
# Epoch 35/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1452 - accuracy: 0.9497
# Epoch 35: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1454 - accuracy: 0.9495 - val_loss: 73.7661 - val_accuracy: 0.6871 - lr: 1.1724e-04
# Epoch 36/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9503
# Epoch 36: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1379 - accuracy: 0.9503 - val_loss: 118.8614 - val_accuracy: 0.6353 - lr: 1.1724e-04
# Epoch 37/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1331 - accuracy: 0.9511
# Epoch 37: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1333 - accuracy: 0.9508 - val_loss: 172.5343 - val_accuracy: 0.6448 - lr: 1.1724e-04
# Epoch 38/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.9537
# Epoch 38: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1344 - accuracy: 0.9537 - val_loss: 255.8096 - val_accuracy: 0.5729 - lr: 1.1724e-04
# Epoch 39/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9572
# Epoch 39: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1297 - accuracy: 0.9572 - val_loss: 208.4546 - val_accuracy: 0.6808 - lr: 1.1724e-04
# Epoch 40/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9529
# Epoch 40: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1280 - accuracy: 0.9529 - val_loss: 259.7320 - val_accuracy: 0.6353 - lr: 1.1724e-04
# Epoch 41/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1253 - accuracy: 0.9534
# Epoch 41: loss did not improve from 0.49794
# 3782/3782 [==============================] - 51s 13ms/step - loss: 0.1261 - accuracy: 0.9532 - val_loss: 179.7104 - val_accuracy: 0.6512 - lr: 1.1724e-04
# Epoch 42/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9551
# Epoch 42: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1239 - accuracy: 0.9551 - val_loss: 238.7383 - val_accuracy: 0.6237 - lr: 1.1724e-04
# Epoch 43/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1268 - accuracy: 0.9571
# Epoch 43: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1266 - accuracy: 0.9572 - val_loss: 292.0645 - val_accuracy: 0.6247 - lr: 1.1724e-04
# Epoch 44/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1245 - accuracy: 0.9569
# Epoch 44: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1245 - accuracy: 0.9569 - val_loss: 309.9602 - val_accuracy: 0.5920 - lr: 1.1724e-04
# Epoch 45/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9593
# Epoch 45: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1205 - accuracy: 0.9593 - val_loss: 424.1301 - val_accuracy: 0.5349 - lr: 1.1724e-04
# Epoch 46/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1205 - accuracy: 0.9574
# Epoch 46: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1204 - accuracy: 0.9574 - val_loss: 444.0031 - val_accuracy: 0.5994 - lr: 1.1724e-04
# Epoch 47/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9556
# Epoch 47: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1222 - accuracy: 0.9556 - val_loss: 312.4728 - val_accuracy: 0.5550 - lr: 1.1724e-04
# Epoch 48/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9537
# Epoch 48: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1270 - accuracy: 0.9537 - val_loss: 443.2404 - val_accuracy: 0.5529 - lr: 1.1724e-04
# Epoch 49/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9574
# Epoch 49: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1205 - accuracy: 0.9574 - val_loss: 492.3354 - val_accuracy: 0.5476 - lr: 1.1724e-04
# Epoch 50/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1202 - accuracy: 0.9569
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.3448800493497402e-05.
#
# Epoch 50: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1204 - accuracy: 0.9566 - val_loss: 401.0034 - val_accuracy: 0.5581 - lr: 1.1724e-04
# Epoch 51/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9606
# Epoch 51: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 12ms/step - loss: 0.1145 - accuracy: 0.9606 - val_loss: 399.9291 - val_accuracy: 0.5486 - lr: 2.3449e-05
# Epoch 52/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9600
# Epoch 52: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1125 - accuracy: 0.9601 - val_loss: 486.5341 - val_accuracy: 0.5539 - lr: 2.3449e-05
# Epoch 53/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1092 - accuracy: 0.9632
# Epoch 53: loss did not improve from 0.49794
# 3782/3782 [==============================] - 45s 12ms/step - loss: 0.1092 - accuracy: 0.9632 - val_loss: 459.7711 - val_accuracy: 0.5338 - lr: 2.3449e-05
# Epoch 54/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.9608
# Epoch 54: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1129 - accuracy: 0.9609 - val_loss: 380.4872 - val_accuracy: 0.5412 - lr: 2.3449e-05
# Epoch 55/200
# 3776/3782 [============================>.] - ETA: 0s - loss: 0.1136 - accuracy: 0.9608
# Epoch 55: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1135 - accuracy: 0.9609 - val_loss: 506.1390 - val_accuracy: 0.5349 - lr: 2.3449e-05
# Epoch 56/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1096 - accuracy: 0.9630
# Epoch 56: loss did not improve from 0.49794
# 3782/3782 [==============================] - 46s 12ms/step - loss: 0.1096 - accuracy: 0.9630 - val_loss: 415.7776 - val_accuracy: 0.5497 - lr: 2.3449e-05
# Epoch 57/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.9635
# Epoch 57: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 13ms/step - loss: 0.1130 - accuracy: 0.9635 - val_loss: 522.5474 - val_accuracy: 0.5359 - lr: 2.3449e-05
# Epoch 58/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9601
# Epoch 58: ReduceLROnPlateau reducing learning rate to 4.6897599531803285e-06.
#
# Epoch 58: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1114 - accuracy: 0.9601 - val_loss: 496.1626 - val_accuracy: 0.5666 - lr: 2.3449e-05
# Epoch 59/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.9643
# Epoch 59: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1138 - accuracy: 0.9643 - val_loss: 1123.3121 - val_accuracy: 0.5391 - lr: 4.6898e-06
# Epoch 60/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1067 - accuracy: 0.9611
# Epoch 60: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1067 - accuracy: 0.9611 - val_loss: 405.2112 - val_accuracy: 0.5465 - lr: 4.6898e-06
# Epoch 61/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9611
# Epoch 61: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 13ms/step - loss: 0.1063 - accuracy: 0.9611 - val_loss: 495.5035 - val_accuracy: 0.5381 - lr: 4.6898e-06
# Epoch 62/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9627
# Epoch 62: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1065 - accuracy: 0.9627 - val_loss: 428.7444 - val_accuracy: 0.5296 - lr: 4.6898e-06
# Epoch 63/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1068 - accuracy: 0.9651
# Epoch 63: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1067 - accuracy: 0.9651 - val_loss: 491.4810 - val_accuracy: 0.5507 - lr: 4.6898e-06
# Epoch 64/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9635
# Epoch 64: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1073 - accuracy: 0.9635 - val_loss: 886.3955 - val_accuracy: 0.5032 - lr: 4.6898e-06
# Epoch 65/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.9603
# Epoch 65: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1112 - accuracy: 0.9603 - val_loss: 587.8039 - val_accuracy: 0.5201 - lr: 4.6898e-06
# Epoch 66/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9632
# Epoch 66: loss did not improve from 0.49794
# 3782/3782 [==============================] - 47s 13ms/step - loss: 0.1048 - accuracy: 0.9632 - val_loss: 467.5112 - val_accuracy: 0.5560 - lr: 4.6898e-06
# Epoch 67/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9629
# Epoch 67: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1054 - accuracy: 0.9630 - val_loss: 386.3835 - val_accuracy: 0.5074 - lr: 4.6898e-06
# Epoch 68/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9638
# Epoch 68: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1039 - accuracy: 0.9638 - val_loss: 393.6150 - val_accuracy: 0.5581 - lr: 4.6898e-06
# Epoch 69/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9619
# Epoch 69: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1057 - accuracy: 0.9619 - val_loss: 396.0929 - val_accuracy: 0.5275 - lr: 4.6898e-06
# Epoch 70/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9630
# Epoch 70: loss did not improve from 0.49794
# 3782/3782 [==============================] - 53s 14ms/step - loss: 0.1052 - accuracy: 0.9630 - val_loss: 452.4229 - val_accuracy: 0.5307 - lr: 4.6898e-06
# Epoch 71/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.9638
# Epoch 71: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1050 - accuracy: 0.9638 - val_loss: 464.8115 - val_accuracy: 0.5264 - lr: 4.6898e-06
# Epoch 72/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9632
# Epoch 72: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1045 - accuracy: 0.9632 - val_loss: 396.3922 - val_accuracy: 0.5338 - lr: 4.6898e-06
# Epoch 73/200
# 3775/3782 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9616
# Epoch 73: ReduceLROnPlateau reducing learning rate to 9.379519724461717e-07.
#
# Epoch 73: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1045 - accuracy: 0.9614 - val_loss: 540.8569 - val_accuracy: 0.5233 - lr: 4.6898e-06
# Epoch 74/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9619
# Epoch 74: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1064 - accuracy: 0.9619 - val_loss: 445.7592 - val_accuracy: 0.5296 - lr: 9.3795e-07
# Epoch 75/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.9619
# Epoch 75: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1061 - accuracy: 0.9619 - val_loss: 659.3356 - val_accuracy: 0.5190 - lr: 9.3795e-07
# Epoch 76/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9635
# Epoch 76: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1034 - accuracy: 0.9635 - val_loss: 520.8760 - val_accuracy: 0.5317 - lr: 9.3795e-07
# Epoch 77/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9625
# Epoch 77: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1065 - accuracy: 0.9625 - val_loss: 738.5474 - val_accuracy: 0.5074 - lr: 9.3795e-07
# Epoch 78/200
# 3780/3782 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9646
# Epoch 78: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1048 - accuracy: 0.9646 - val_loss: 483.1408 - val_accuracy: 0.5486 - lr: 9.3795e-07
# Epoch 79/200
# 3779/3782 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9637
# Epoch 79: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1065 - accuracy: 0.9638 - val_loss: 835.6678 - val_accuracy: 0.5106 - lr: 9.3795e-07
# Epoch 80/200
# 3781/3782 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9643
# Epoch 80: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1065 - accuracy: 0.9643 - val_loss: 430.6110 - val_accuracy: 0.5370 - lr: 9.3795e-07
# Epoch 81/200
# 3774/3782 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9626
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1.8759039903670783e-07.
#
# Epoch 81: loss did not improve from 0.49794
# 3782/3782 [==============================] - 50s 13ms/step - loss: 0.1054 - accuracy: 0.9627 - val_loss: 526.7557 - val_accuracy: 0.5328 - lr: 9.3795e-07
# Epoch 82/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1046 - accuracy: 0.9632
# Epoch 82: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1045 - accuracy: 0.9632 - val_loss: 441.0305 - val_accuracy: 0.5677 - lr: 1.8759e-07
# Epoch 83/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1069 - accuracy: 0.9627
# Epoch 83: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1069 - accuracy: 0.9627 - val_loss: 897.2187 - val_accuracy: 0.5106 - lr: 1.8759e-07
# Epoch 84/200
# 3782/3782 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9651
# Epoch 84: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1042 - accuracy: 0.9651 - val_loss: 473.4364 - val_accuracy: 0.5137 - lr: 1.8759e-07
# Epoch 85/200
# 3778/3782 [============================>.] - ETA: 0s - loss: 0.1036 - accuracy: 0.9619
# Epoch 85: loss did not improve from 0.49794
# 3782/3782 [==============================] - 49s 13ms/step - loss: 0.1036 - accuracy: 0.9619 - val_loss: 623.2310 - val_accuracy: 0.5264 - lr: 1.8759e-07
# Epoch 86/200
# 3777/3782 [============================>.] - ETA: 0s - loss: 0.1057 - accuracy: 0.9624
# Epoch 86: ReduceLROnPlateau reducing learning rate to 3.7518080375775756e-08.
#
# Epoch 86: loss did not improve from 0.49794
# 3782/3782 [==============================] - 48s 13ms/step - loss: 0.1056 - accuracy: 0.9625 - val_loss: 465.0097 - val_accuracy: 0.5402 - lr: 1.8759e-07
# Epoch 86: early stopping

# %%
model.evaluate(X_test, y_test)
# Out:
# 148/148 [==============================] - 5s 9ms/step - loss: 3711.1218 - accuracy: 0.5025
# [3711.121826171875, 0.5025380849838257]

# %%
predictions = model.predict(X_test).astype("int").flatten()
# Out:
# 148/148 [==============================] - 4s 8ms/step

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predictions, normalize='true', values_format='.0%')
plt.show()

# %%
print(f'Recall: {recall_score(y_test, predictions)}')
print(f'Precision: {precision_score(y_test, predictions)}')
# Out:
# Recall: 0.6757662835249042
# Precision: 0.4469433006018372

# %%
model.save(f'{modelpath}/cnnTradingCSNA.h5')
