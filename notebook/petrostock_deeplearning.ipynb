# %% [markdown]
# # MBA em Ciência de Dados e Inteligência Artificial - FIAP - 2024
# # Projeto Integrado - Deep Learning

# %% [markdown]
# ## Descrição do Projeto:
#
# A QuantumFinance está desejando construir um fundo de ações baseado em modelos de Deep Learning. A ideia é desenvolver um modelo que tenha como saída a compra ou venda de uma determinada ação baseado na movimentação do mercado nos últimos 15 dias.

# %% [markdown]
# ## O Desafio:
# A empresa deseja um modelo de Deep Learning que seja um ‘perseguidor de tendencia’, ou seja, se o papel sobe o modelo deve comprar, se o papel desce o
# modelo deve vender. Para isso a QuantumFinance contratou economistas que fizerem a rotulagem dos dados baseado no valor de fechamento dos ativos. Inicialmente foi feita uma suavização dos preços de fechamento, e por se tratar de um assunto sigiloso, não foi informada a técnica de suavização utilizada. O próximo passo foi realizar a rotulagem dia a dia, para verificar qual devemos comprar e qual devemos vender.

# %% [markdown]
# Para esse notebook, contemplo uma arquitetura simples de redes utilizando CNN + LSTM. Essa arquitetura foi baseada em artigos para finalidade de estudo, disponíveis através do arquivo README.md, utilizando a ação VALE3 - Vale do Rio Doce para ajustes. Como bônus, abordo outras 3 ações (BBAS3 - Banco do Brasil, CSNA3 - Companhia Siderúrgica Nacional, PETR4 - Petrobras) para avaliar como a rede se comporta com outras ações.

# %%
from pathlib import Path 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.graph_objects as go

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import ConfusionMatrixDisplay, recall_score, precision_score

from keras.models import Sequential
from keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, Dense, LSTM, Bidirectional
from keras.regularizers import l1_l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras_tuner.tuners import Hyperband

import warnings
warnings.filterwarnings('ignore')

# %%
datapath = Path('../data')
modelpath = Path('../model')

# %%
data = pd.read_csv(f'{datapath}/csv/PETR4train.csv')
data = data[['Date', 'Smoothed_Close', 'Label']]
data.head()
# Out:
#          Date  Smoothed_Close  Label
# 0  2000-01-24        1.347845     -1
# 1  2000-01-25        1.340540     -1
# 2  2000-01-26        1.335495     -1
# 3  2000-01-27        1.330042     -1
# 4  2000-01-28        1.325134     -1

# %%
data['Label'].value_counts()
# Out:
# -1    2654
#  1    2154
# Name: Label, dtype: int64

# %%
class LabelTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        X = X.copy()
        X.loc[X['Label'] == -1, 'Label'] = 0
        return X

# %%
data_test = pd.read_csv(f'{datapath}/csv/PETR4test.csv')
data_test = data_test[['Smoothed_Close', 'Label']]

# %%
label_transformer = LabelTransformer()
data = label_transformer.fit_transform(data)
data_test = label_transformer.transform(data_test)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4808 entries, 0 to 4807
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            4808 non-null   object
#  1   Smoothed_Close  4808 non-null   float64
#  2   Label           4808 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 112.8+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Year'] = data['Date'].dt.year

# %%
fig = go.Figure()

for year in data['Year'].unique():
    year_data = data[data['Year'] == year]
    fig.add_trace(go.Scatter(x=year_data['Date'], y=year_data['Smoothed_Close'],
                             mode='lines', name=str(year)))

for label, name, color in zip([0, 1], ['Venda', 'Compra'], ['red', 'green']):
    label_data = data[data['Label'] == label]
    fig.add_trace(go.Scatter(x=label_data['Date'], y=label_data['Smoothed_Close'],
                             mode='markers', name=name, marker_color=color))

fig.update_layout(title='PETR4 - Petrobras',
                  xaxis_title='Anos',
                  yaxis_title='Preços de Fechamento',
                  legend_title='Legenda')

fig.show()

# %%
data.drop(['Date', 'Year'], axis=1, inplace=True)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close = scaler.fit_transform(data[['Smoothed_Close']])
scaled_close_test = scaler.transform(data_test[['Smoothed_Close']])

# %%
data['Scaled_Close'] = scaled_close.flatten()
data_test['Scaled_Close'] = scaled_close_test.flatten()

# %%
def create_window(data, label, window_size=15):
    X, y = [], []
    cumulative_avg = np.cumsum(data) / np.arange(1, len(data) + 1)

    for i in range(len(data) - window_size):
        window = data[i:(i + window_size)]
        window = np.append(window, cumulative_avg[i + window_size - 1])
        window = np.expand_dims(window, axis=-1)
        X.append(window)
        y.append(label[i + window_size])

    return np.array(X), np.array(y)

# %%
X_train, y_train = create_window(data=data['Scaled_Close'], label=data['Label'], window_size=15)
X_test, y_test = create_window(data=data['Scaled_Close'], label=data['Label'], window_size=15)

# %%
def rede_cnnTrading(hp):
    model = Sequential()
    model.add(Conv1D(
        filters=hp.Int('filters_1', min_value=32, max_value=64, step=32),
        kernel_size=hp.Choice('kernel_size_1', values=[2, 3]),
        activation=hp.Choice('activ1', values=['relu', 'tanh', 'elu']),
        padding='same', kernel_initializer='he_uniform', input_shape=(16, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=hp.Choice('pool1', values=[1, 2])))
    # model.add(Conv1D(
    #     filters=hp.Int('filters_2', min_value=32, max_value=128, step=32),
    #     kernel_size=hp.Choice('kernel_size_2', values=[2, 3]),
    #     activation=hp.Choice('activ2', values=['relu', 'tanh', 'elu']),
    #     padding='same', kernel_initializer='he_uniform'))
    # model.add(BatchNormalization())
    # model.add(MaxPooling1D(pool_size=hp.Choice('poo2', values=[1, 2])))
    # model.add(Conv1D(
    #     filters=hp.Int('filters_3', min_value=32, max_value=64, step=32),
    #     kernel_size=hp.Choice('kernel_size_3', values=[2, 3]),
    #     activation=hp.Choice('activ3', values=['relu', 'tanh', 'elu']),
    #     padding='same', kernel_initializer='he_uniform'))
    # model.add(MaxPooling1D(pool_size=hp.Choice('poo3', values=[1, 2])))
    # model.add(Bidirectional(LSTM(
    #     units=hp.Int('lstm_units1', min_value=50, max_value=100, step=50),
    #     activation=hp.Choice('actv3', values=['relu', 'tanh', 'elu']), return_sequences=True, kernel_initializer='he_uniform')))
    # model.add(Dropout(hp.Float('dropout_rate1', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(Bidirectional(LSTM(
        units=hp.Int('lstm_units2', min_value=50, max_value=100, step=50),
        activation=hp.Choice('actv4', values=['relu', 'tanh', 'elu']), kernel_initializer='he_uniform')))
    # model.add(Dropout(hp.Float('dropout_rate2', min_value=0.0, max_value=0.5, step=0.1)))
    # model.add(TimeDistributed(Dense(units=1, activation=hp.Choice('activ2', values=['relu', 'tanh']), kernel_initializer='he_uniform')))
    model.add(Dropout(hp.Float('dropout_rate3', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(Dense(units=1, activation='sigmoid', kernel_initializer='he_uniform',
                                    kernel_regularizer=l1_l2(l1=hp.Float('l1', min_value=0.0, max_value=0.05, step=0.01), l2=hp.Float('l1', min_value=0.0, max_value=0.05, step=0.01))))
    model.compile(optimizer=Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-3, sampling='LOG')),
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = Hyperband(
    rede_cnnTrading,
    objective='val_accuracy',
    max_epochs=100,
    directory=f'{modelpath}',
    project_name='hparam_tuning')
# Out:
# Reloading Tuner from ..\model\hparam_tuning\tuner0.json

# %%
es = EarlyStopping(monitor='loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, verbose=1)
mcp = ModelCheckpoint(filepath=f'{modelpath}/pesosPTRB.h5', monitor='loss', save_best_only=True, verbose=1, mode='max')
callbacks = [es, rlr, mcp]

# %%
train_size = int(len(X_train) * 0.8)
X_train_split, X_val_split = X_train[:train_size], X_train[train_size:]
y_train_split, y_val_split = y_train[:train_size], y_train[train_size:]

# %%
tuner.search(X_train, y_train, validation_data=(X_val_split, y_val_split), epochs=100, callbacks=[es, rlr, mcp], batch_size=1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='elu', padding='same', kernel_initializer='he_uniform', input_shape=(16, 1)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(units=50, activation='relu', kernel_initializer='he_uniform')))
model.add(Dropout(0.3))
model.add(Dense(units=1, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l1_l2(l1=0.02, l2=0.02)))
model.compile(optimizer=Adam(learning_rate=0.00058622), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TradingClassifierPetrobras = model.fit(X_train_split, y_train_split, epochs=200, batch_size=1, validation_data=(X_val_split, y_val_split), callbacks=[es, rlr, mcp])
# Out:
# Epoch 1/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.6080 - accuracy: 0.7472
# Epoch 1: loss improved from -inf to 0.60817, saving model to ..\model\pesosPTRB.h5
# 3834/3834 [==============================] - 18s 4ms/step - loss: 0.6082 - accuracy: 0.7473 - val_loss: 5.1877 - val_accuracy: 0.5443 - lr: 5.8622e-04
# Epoch 2/200
# 3821/3834 [============================>.] - ETA: 0s - loss: 0.3909 - accuracy: 0.8427
# Epoch 2: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.3904 - accuracy: 0.8430 - val_loss: 5.4516 - val_accuracy: 0.6298 - lr: 5.8622e-04
# Epoch 3/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8725
# Epoch 3: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.3262 - accuracy: 0.8725 - val_loss: 4.2484 - val_accuracy: 0.6517 - lr: 5.8622e-04
# Epoch 4/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.2990 - accuracy: 0.8849
# Epoch 4: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2984 - accuracy: 0.8852 - val_loss: 5.0300 - val_accuracy: 0.6298 - lr: 5.8622e-04
# Epoch 5/200
# 3821/3834 [============================>.] - ETA: 0s - loss: 0.2789 - accuracy: 0.8937
# Epoch 5: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2794 - accuracy: 0.8938 - val_loss: 4.5591 - val_accuracy: 0.6517 - lr: 5.8622e-04
# Epoch 6/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.2831 - accuracy: 0.8908
# Epoch 6: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2828 - accuracy: 0.8910 - val_loss: 5.9275 - val_accuracy: 0.5965 - lr: 5.8622e-04
# Epoch 7/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.2588 - accuracy: 0.9005
# Epoch 7: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2596 - accuracy: 0.9004 - val_loss: 2.7159 - val_accuracy: 0.7007 - lr: 5.8622e-04
# Epoch 8/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.2527 - accuracy: 0.9043
# Epoch 8: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2530 - accuracy: 0.9040 - val_loss: 3.0258 - val_accuracy: 0.7435 - lr: 5.8622e-04
# Epoch 9/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.2545 - accuracy: 0.9022
# Epoch 9: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2542 - accuracy: 0.9025 - val_loss: 3.3129 - val_accuracy: 0.6277 - lr: 5.8622e-04
# Epoch 10/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.2356 - accuracy: 0.9086
# Epoch 10: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2355 - accuracy: 0.9087 - val_loss: 2.7782 - val_accuracy: 0.6465 - lr: 5.8622e-04
# Epoch 11/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9090
# Epoch 11: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2399 - accuracy: 0.9090 - val_loss: 4.3659 - val_accuracy: 0.7007 - lr: 5.8622e-04
# Epoch 12/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.2327 - accuracy: 0.9129
# Epoch 12: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2322 - accuracy: 0.9131 - val_loss: 4.4684 - val_accuracy: 0.6350 - lr: 5.8622e-04
# Epoch 13/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9181
# Epoch 13: loss did not improve from 0.60817
# 3834/3834 [==============================] - 16s 4ms/step - loss: 0.2225 - accuracy: 0.9181 - val_loss: 4.8164 - val_accuracy: 0.6298 - lr: 5.8622e-04
# Epoch 14/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.2252 - accuracy: 0.9146
# Epoch 14: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2258 - accuracy: 0.9144 - val_loss: 6.9766 - val_accuracy: 0.6840 - lr: 5.8622e-04
# Epoch 15/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.2198 - accuracy: 0.9199
# Epoch 15: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2198 - accuracy: 0.9199 - val_loss: 2.6270 - val_accuracy: 0.6799 - lr: 5.8622e-04
# Epoch 16/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.2107 - accuracy: 0.9209
# Epoch 16: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2109 - accuracy: 0.9207 - val_loss: 3.6244 - val_accuracy: 0.6726 - lr: 5.8622e-04
# Epoch 17/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.2117 - accuracy: 0.9215
# Epoch 17: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2117 - accuracy: 0.9215 - val_loss: 3.0976 - val_accuracy: 0.6747 - lr: 5.8622e-04
# Epoch 18/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.2087 - accuracy: 0.9237
# Epoch 18: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.2085 - accuracy: 0.9238 - val_loss: 4.4472 - val_accuracy: 0.6486 - lr: 5.8622e-04
# Epoch 19/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.2082 - accuracy: 0.9224
# Epoch 19: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.2080 - accuracy: 0.9225 - val_loss: 2.7173 - val_accuracy: 0.6715 - lr: 5.8622e-04
# Epoch 20/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.2110 - accuracy: 0.9169
# Epoch 20: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2116 - accuracy: 0.9168 - val_loss: 3.4355 - val_accuracy: 0.6715 - lr: 5.8622e-04
# Epoch 21/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.9217
# Epoch 21: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.2046 - accuracy: 0.9218 - val_loss: 2.3880 - val_accuracy: 0.6392 - lr: 5.8622e-04
# Epoch 22/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.2034 - accuracy: 0.9284
# Epoch 22: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2033 - accuracy: 0.9285 - val_loss: 2.3131 - val_accuracy: 0.7049 - lr: 5.8622e-04
# Epoch 23/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.2018 - accuracy: 0.9217
# Epoch 23: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2018 - accuracy: 0.9218 - val_loss: 1.8939 - val_accuracy: 0.6517 - lr: 5.8622e-04
# Epoch 24/200
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.1950 - accuracy: 0.9292
# Epoch 24: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1949 - accuracy: 0.9293 - val_loss: 3.4701 - val_accuracy: 0.6319 - lr: 5.8622e-04
# Epoch 25/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.9258
# Epoch 25: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.2044 - accuracy: 0.9257 - val_loss: 3.8928 - val_accuracy: 0.6767 - lr: 5.8622e-04
# Epoch 26/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.1938 - accuracy: 0.9287
# Epoch 26: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1940 - accuracy: 0.9285 - val_loss: 3.2196 - val_accuracy: 0.6507 - lr: 5.8622e-04
# Epoch 27/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9295
# Epoch 27: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1938 - accuracy: 0.9291 - val_loss: 2.4503 - val_accuracy: 0.6475 - lr: 5.8622e-04
# Epoch 28/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9286
# Epoch 28: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.1924 - accuracy: 0.9288 - val_loss: 2.8315 - val_accuracy: 0.7299 - lr: 5.8622e-04
# Epoch 29/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9259
# Epoch 29: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1973 - accuracy: 0.9259 - val_loss: 4.2685 - val_accuracy: 0.6444 - lr: 5.8622e-04
# Epoch 30/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9293
# Epoch 30: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1919 - accuracy: 0.9293 - val_loss: 4.3392 - val_accuracy: 0.6444 - lr: 5.8622e-04
# Epoch 31/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1917 - accuracy: 0.9315
# Epoch 31: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.1918 - accuracy: 0.9317 - val_loss: 2.1661 - val_accuracy: 0.6548 - lr: 5.8622e-04
# Epoch 32/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1894 - accuracy: 0.9334
# Epoch 32: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.1893 - accuracy: 0.9335 - val_loss: 2.6902 - val_accuracy: 0.7101 - lr: 5.8622e-04
# Epoch 33/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.1793 - accuracy: 0.9299
# Epoch 33: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.1794 - accuracy: 0.9298 - val_loss: 3.2513 - val_accuracy: 0.6434 - lr: 5.8622e-04
# Epoch 34/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.1836 - accuracy: 0.9303
# Epoch 34: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1834 - accuracy: 0.9304 - val_loss: 3.6567 - val_accuracy: 0.6997 - lr: 5.8622e-04
# Epoch 35/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.1843 - accuracy: 0.9337
# Epoch 35: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1842 - accuracy: 0.9338 - val_loss: 3.2780 - val_accuracy: 0.6840 - lr: 5.8622e-04
# Epoch 36/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1796 - accuracy: 0.9307
# Epoch 36: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1798 - accuracy: 0.9306 - val_loss: 4.0003 - val_accuracy: 0.6851 - lr: 5.8622e-04
# Epoch 37/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.9332
# Epoch 37: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.1810 - accuracy: 0.9332 - val_loss: 3.3394 - val_accuracy: 0.6840 - lr: 5.8622e-04
# Epoch 38/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.1769 - accuracy: 0.9368
# Epoch 38: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1772 - accuracy: 0.9366 - val_loss: 3.1223 - val_accuracy: 0.6621 - lr: 5.8622e-04
# Epoch 39/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.1793 - accuracy: 0.9360
# Epoch 39: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1792 - accuracy: 0.9361 - val_loss: 4.2187 - val_accuracy: 0.7049 - lr: 5.8622e-04
# Epoch 40/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.1786 - accuracy: 0.9344
# Epoch 40: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1786 - accuracy: 0.9343 - val_loss: 2.9495 - val_accuracy: 0.7185 - lr: 5.8622e-04
# Epoch 41/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.1927 - accuracy: 0.9332
# Epoch 41: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1926 - accuracy: 0.9332 - val_loss: 2.9602 - val_accuracy: 0.6142 - lr: 5.8622e-04
# Epoch 42/200
# 3821/3834 [============================>.] - ETA: 0s - loss: 0.1721 - accuracy: 0.9317
# Epoch 42: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.1722 - accuracy: 0.9314 - val_loss: 2.9389 - val_accuracy: 0.6225 - lr: 5.8622e-04
# Epoch 43/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.1723 - accuracy: 0.9351
# Epoch 43: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1722 - accuracy: 0.9353 - val_loss: 5.5319 - val_accuracy: 0.6413 - lr: 5.8622e-04
# Epoch 44/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.1825 - accuracy: 0.9323
# Epoch 44: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1827 - accuracy: 0.9322 - val_loss: 5.9805 - val_accuracy: 0.6319 - lr: 5.8622e-04
# Epoch 45/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9345
# Epoch 45: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1668 - accuracy: 0.9345 - val_loss: 6.3792 - val_accuracy: 0.6382 - lr: 5.8622e-04
# Epoch 46/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1802 - accuracy: 0.9378
# Epoch 46: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1800 - accuracy: 0.9379 - val_loss: 6.0763 - val_accuracy: 0.6851 - lr: 5.8622e-04
# Epoch 47/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.1698 - accuracy: 0.9349
# Epoch 47: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1705 - accuracy: 0.9345 - val_loss: 4.2604 - val_accuracy: 0.6903 - lr: 5.8622e-04
# Epoch 48/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9339
# Epoch 48: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1796 - accuracy: 0.9338 - val_loss: 3.3982 - val_accuracy: 0.6820 - lr: 5.8622e-04
# Epoch 49/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9370
# Epoch 49: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1735 - accuracy: 0.9369 - val_loss: 7.3675 - val_accuracy: 0.6642 - lr: 5.8622e-04
# Epoch 50/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9365
# Epoch 50: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.1656 - accuracy: 0.9366 - val_loss: 7.4118 - val_accuracy: 0.6277 - lr: 5.8622e-04
# Epoch 51/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.1749 - accuracy: 0.9358
# Epoch 51: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1748 - accuracy: 0.9358 - val_loss: 10.5608 - val_accuracy: 0.6809 - lr: 5.8622e-04
# Epoch 52/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9354
# Epoch 52: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1749 - accuracy: 0.9356 - val_loss: 9.9906 - val_accuracy: 0.6371 - lr: 5.8622e-04
# Epoch 53/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.1747 - accuracy: 0.9381
# Epoch 53: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1753 - accuracy: 0.9379 - val_loss: 4.5644 - val_accuracy: 0.6246 - lr: 5.8622e-04
# Epoch 54/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.1750 - accuracy: 0.9391
# Epoch 54: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1747 - accuracy: 0.9392 - val_loss: 4.5749 - val_accuracy: 0.6747 - lr: 5.8622e-04
# Epoch 55/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1691 - accuracy: 0.9407
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00011724400101229549.
#
# Epoch 55: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1692 - accuracy: 0.9403 - val_loss: 4.5749 - val_accuracy: 0.6809 - lr: 5.8622e-04
# Epoch 56/200
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9511
# Epoch 56: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1420 - accuracy: 0.9512 - val_loss: 13.4050 - val_accuracy: 0.6225 - lr: 1.1724e-04
# Epoch 57/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9528
# Epoch 57: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1313 - accuracy: 0.9528 - val_loss: 15.1930 - val_accuracy: 0.5985 - lr: 1.1724e-04
# Epoch 58/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.1285 - accuracy: 0.9524
# Epoch 58: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1289 - accuracy: 0.9523 - val_loss: 12.7083 - val_accuracy: 0.6496 - lr: 1.1724e-04
# Epoch 59/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.1256 - accuracy: 0.9548
# Epoch 59: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1254 - accuracy: 0.9549 - val_loss: 20.5740 - val_accuracy: 0.6079 - lr: 1.1724e-04
# Epoch 60/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9551
# Epoch 60: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1266 - accuracy: 0.9551 - val_loss: 13.8678 - val_accuracy: 0.6048 - lr: 1.1724e-04
# Epoch 61/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9556
# Epoch 61: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1213 - accuracy: 0.9557 - val_loss: 23.8164 - val_accuracy: 0.5839 - lr: 1.1724e-04
# Epoch 62/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.9563
# Epoch 62: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1153 - accuracy: 0.9562 - val_loss: 24.1944 - val_accuracy: 0.5923 - lr: 1.1724e-04
# Epoch 63/200
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.1208 - accuracy: 0.9579
# Epoch 63: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1207 - accuracy: 0.9580 - val_loss: 15.5834 - val_accuracy: 0.6121 - lr: 1.1724e-04
# Epoch 64/200
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.1149 - accuracy: 0.9600
# Epoch 64: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1148 - accuracy: 0.9601 - val_loss: 21.6328 - val_accuracy: 0.6111 - lr: 1.1724e-04
# Epoch 65/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9583
# Epoch 65: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1153 - accuracy: 0.9583 - val_loss: 22.5185 - val_accuracy: 0.6246 - lr: 1.1724e-04
# Epoch 66/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9610
# Epoch 66: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1152 - accuracy: 0.9609 - val_loss: 19.1397 - val_accuracy: 0.5933 - lr: 1.1724e-04
# Epoch 67/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.1102 - accuracy: 0.9613
# Epoch 67: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1110 - accuracy: 0.9609 - val_loss: 23.1370 - val_accuracy: 0.6152 - lr: 1.1724e-04
# Epoch 68/200
# 3825/3834 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9576
# Epoch 68: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1132 - accuracy: 0.9577 - val_loss: 31.0592 - val_accuracy: 0.6058 - lr: 1.1724e-04
# Epoch 69/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.1085 - accuracy: 0.9622
# Epoch 69: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1092 - accuracy: 0.9619 - val_loss: 28.1385 - val_accuracy: 0.5600 - lr: 1.1724e-04
# Epoch 70/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9597
# Epoch 70: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1105 - accuracy: 0.9598 - val_loss: 20.3644 - val_accuracy: 0.5871 - lr: 1.1724e-04
# Epoch 71/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1091 - accuracy: 0.9631
# Epoch 71: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1089 - accuracy: 0.9632 - val_loss: 22.0933 - val_accuracy: 0.5756 - lr: 1.1724e-04
# Epoch 72/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.1101 - accuracy: 0.9603
# Epoch 72: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1101 - accuracy: 0.9604 - val_loss: 29.9461 - val_accuracy: 0.6058 - lr: 1.1724e-04
# Epoch 73/200
# 3831/3834 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9622
# Epoch 73: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1087 - accuracy: 0.9622 - val_loss: 40.4395 - val_accuracy: 0.5777 - lr: 1.1724e-04
# Epoch 74/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9639
# Epoch 74: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1082 - accuracy: 0.9637 - val_loss: 39.3768 - val_accuracy: 0.5662 - lr: 1.1724e-04
# Epoch 75/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9631
# Epoch 75: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1167 - accuracy: 0.9632 - val_loss: 23.3989 - val_accuracy: 0.6246 - lr: 1.1724e-04
# Epoch 76/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9614
# Epoch 76: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1095 - accuracy: 0.9614 - val_loss: 23.2687 - val_accuracy: 0.5631 - lr: 1.1724e-04
# Epoch 77/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9635
# Epoch 77: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1041 - accuracy: 0.9635 - val_loss: 23.3839 - val_accuracy: 0.6006 - lr: 1.1724e-04
# Epoch 78/200
# 3825/3834 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9631
# Epoch 78: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1068 - accuracy: 0.9632 - val_loss: 23.9735 - val_accuracy: 0.5610 - lr: 1.1724e-04
# Epoch 79/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9627
# Epoch 79: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1042 - accuracy: 0.9627 - val_loss: 26.8353 - val_accuracy: 0.5777 - lr: 1.1724e-04
# Epoch 80/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9645
# Epoch 80: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.1042 - accuracy: 0.9645 - val_loss: 26.3268 - val_accuracy: 0.6058 - lr: 1.1724e-04
# Epoch 81/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9632
# Epoch 81: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.1068 - accuracy: 0.9632 - val_loss: 25.4248 - val_accuracy: 0.6131 - lr: 1.1724e-04
# Epoch 82/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9661
# Epoch 82: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0996 - accuracy: 0.9661 - val_loss: 29.8275 - val_accuracy: 0.6069 - lr: 1.1724e-04
# Epoch 83/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9657
# Epoch 83: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.1041 - accuracy: 0.9658 - val_loss: 26.0048 - val_accuracy: 0.5985 - lr: 1.1724e-04
# Epoch 84/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9655
# Epoch 84: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1076 - accuracy: 0.9656 - val_loss: 24.0780 - val_accuracy: 0.5756 - lr: 1.1724e-04
# Epoch 85/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9684
# Epoch 85: loss did not improve from 0.60817
# 3834/3834 [==============================] - 19s 5ms/step - loss: 0.0956 - accuracy: 0.9684 - val_loss: 22.6879 - val_accuracy: 0.6163 - lr: 1.1724e-04
# Epoch 86/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9655
# Epoch 86: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0968 - accuracy: 0.9656 - val_loss: 30.6383 - val_accuracy: 0.5589 - lr: 1.1724e-04
# Epoch 87/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9658
# Epoch 87: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.1023 - accuracy: 0.9658 - val_loss: 32.1175 - val_accuracy: 0.5829 - lr: 1.1724e-04
# Epoch 88/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.0985 - accuracy: 0.9642
# Epoch 88: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.0989 - accuracy: 0.9637 - val_loss: 30.2994 - val_accuracy: 0.5631 - lr: 1.1724e-04
# Epoch 89/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9664
# Epoch 89: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.1062 - accuracy: 0.9664 - val_loss: 25.7250 - val_accuracy: 0.6121 - lr: 1.1724e-04
# Epoch 90/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.0963 - accuracy: 0.9676
# Epoch 90: ReduceLROnPlateau reducing learning rate to 2.3448800493497402e-05.
#
# Epoch 90: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.0961 - accuracy: 0.9677 - val_loss: 16.2476 - val_accuracy: 0.6340 - lr: 1.1724e-04
# Epoch 91/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9703
# Epoch 91: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0917 - accuracy: 0.9703 - val_loss: 23.6419 - val_accuracy: 0.5933 - lr: 2.3449e-05
# Epoch 92/200
# 3825/3834 [============================>.] - ETA: 0s - loss: 0.0864 - accuracy: 0.9725
# Epoch 92: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0865 - accuracy: 0.9724 - val_loss: 26.5548 - val_accuracy: 0.5839 - lr: 2.3449e-05
# Epoch 93/200
# 3821/3834 [============================>.] - ETA: 0s - loss: 0.0855 - accuracy: 0.9704
# Epoch 93: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0857 - accuracy: 0.9703 - val_loss: 32.2323 - val_accuracy: 0.5610 - lr: 2.3449e-05
# Epoch 94/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9707
# Epoch 94: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.0844 - accuracy: 0.9708 - val_loss: 28.0328 - val_accuracy: 0.5756 - lr: 2.3449e-05
# Epoch 95/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9684
# Epoch 95: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0868 - accuracy: 0.9684 - val_loss: 37.2918 - val_accuracy: 0.5975 - lr: 2.3449e-05
# Epoch 96/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9736
# Epoch 96: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0837 - accuracy: 0.9734 - val_loss: 32.3766 - val_accuracy: 0.5787 - lr: 2.3449e-05
# Epoch 97/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.0836 - accuracy: 0.9713
# Epoch 97: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0835 - accuracy: 0.9713 - val_loss: 30.7916 - val_accuracy: 0.5798 - lr: 2.3449e-05
# Epoch 98/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9723
# Epoch 98: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.0841 - accuracy: 0.9724 - val_loss: 38.1925 - val_accuracy: 0.5527 - lr: 2.3449e-05
# Epoch 99/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.0879 - accuracy: 0.9710
# Epoch 99: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0878 - accuracy: 0.9710 - val_loss: 34.5879 - val_accuracy: 0.5579 - lr: 2.3449e-05
# Epoch 100/200
# 3825/3834 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9707
# Epoch 100: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.0821 - accuracy: 0.9708 - val_loss: 38.8716 - val_accuracy: 0.5485 - lr: 2.3449e-05
# Epoch 101/200
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9731
# Epoch 101: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0856 - accuracy: 0.9731 - val_loss: 35.6029 - val_accuracy: 0.5839 - lr: 2.3449e-05
# Epoch 102/200
# 3824/3834 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9731
# Epoch 102: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0824 - accuracy: 0.9729 - val_loss: 39.0356 - val_accuracy: 0.5537 - lr: 2.3449e-05
# Epoch 103/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9718
# Epoch 103: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.0835 - accuracy: 0.9718 - val_loss: 37.4796 - val_accuracy: 0.5600 - lr: 2.3449e-05
# Epoch 104/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9726
# Epoch 104: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0824 - accuracy: 0.9726 - val_loss: 35.8101 - val_accuracy: 0.5662 - lr: 2.3449e-05
# Epoch 105/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9723
# Epoch 105: ReduceLROnPlateau reducing learning rate to 4.6897599531803285e-06.
#
# Epoch 105: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.0822 - accuracy: 0.9724 - val_loss: 37.5331 - val_accuracy: 0.5714 - lr: 2.3449e-05
# Epoch 106/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9734
# Epoch 106: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0806 - accuracy: 0.9734 - val_loss: 38.5685 - val_accuracy: 0.5495 - lr: 4.6898e-06
# Epoch 107/200
# 3822/3834 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9733
# Epoch 107: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 5ms/step - loss: 0.0808 - accuracy: 0.9734 - val_loss: 36.3139 - val_accuracy: 0.5662 - lr: 4.6898e-06
# Epoch 108/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9736
# Epoch 108: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0820 - accuracy: 0.9737 - val_loss: 40.4058 - val_accuracy: 0.5464 - lr: 4.6898e-06
# Epoch 109/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.0789 - accuracy: 0.9721
# Epoch 109: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0788 - accuracy: 0.9721 - val_loss: 33.9292 - val_accuracy: 0.5589 - lr: 4.6898e-06
# Epoch 110/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.0795 - accuracy: 0.9731
# Epoch 110: loss did not improve from 0.60817
# 3834/3834 [==============================] - 18s 5ms/step - loss: 0.0795 - accuracy: 0.9731 - val_loss: 35.3589 - val_accuracy: 0.5881 - lr: 4.6898e-06
# Epoch 111/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.0799 - accuracy: 0.9713
# Epoch 111: loss did not improve from 0.60817
# 3834/3834 [==============================] - 17s 4ms/step - loss: 0.0798 - accuracy: 0.9713 - val_loss: 35.9005 - val_accuracy: 0.5641 - lr: 4.6898e-06
# Epoch 112/200
# 3827/3834 [============================>.] - ETA: 0s - loss: 0.0798 - accuracy: 0.9736
# Epoch 112: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0797 - accuracy: 0.9737 - val_loss: 35.6895 - val_accuracy: 0.5829 - lr: 4.6898e-06
# Epoch 113/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9726
# Epoch 113: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0805 - accuracy: 0.9726 - val_loss: 33.1504 - val_accuracy: 0.5808 - lr: 4.6898e-06
# Epoch 114/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.0795 - accuracy: 0.9731
# Epoch 114: ReduceLROnPlateau reducing learning rate to 9.379519724461717e-07.
#
# Epoch 114: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0806 - accuracy: 0.9729 - val_loss: 34.5861 - val_accuracy: 0.5412 - lr: 4.6898e-06
# Epoch 115/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9755
# Epoch 115: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0778 - accuracy: 0.9755 - val_loss: 40.1842 - val_accuracy: 0.5756 - lr: 9.3795e-07
# Epoch 116/200
# 3825/3834 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9728
# Epoch 116: loss did not improve from 0.60817
# 3834/3834 [==============================] - 21s 5ms/step - loss: 0.0780 - accuracy: 0.9729 - val_loss: 37.4937 - val_accuracy: 0.5485 - lr: 9.3795e-07
# Epoch 117/200
# 3830/3834 [============================>.] - ETA: 0s - loss: 0.0808 - accuracy: 0.9742
# Epoch 117: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0808 - accuracy: 0.9742 - val_loss: 36.5028 - val_accuracy: 0.5652 - lr: 9.3795e-07
# Epoch 118/200
# 3834/3834 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9721
# Epoch 118: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0787 - accuracy: 0.9721 - val_loss: 34.6654 - val_accuracy: 0.5589 - lr: 9.3795e-07
# Epoch 119/200
# 3826/3834 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9712
# Epoch 119: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0810 - accuracy: 0.9713 - val_loss: 37.0200 - val_accuracy: 0.5662 - lr: 9.3795e-07
# Epoch 120/200
# 3823/3834 [============================>.] - ETA: 0s - loss: 0.0795 - accuracy: 0.9733
# Epoch 120: ReduceLROnPlateau reducing learning rate to 1.8759039903670783e-07.
#
# Epoch 120: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0794 - accuracy: 0.9734 - val_loss: 37.9021 - val_accuracy: 0.5829 - lr: 9.3795e-07
# Epoch 121/200
# 3829/3834 [============================>.] - ETA: 0s - loss: 0.0786 - accuracy: 0.9726
# Epoch 121: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0787 - accuracy: 0.9724 - val_loss: 37.1635 - val_accuracy: 0.5641 - lr: 1.8759e-07
# Epoch 122/200
# 3832/3834 [============================>.] - ETA: 0s - loss: 0.0800 - accuracy: 0.9729
# Epoch 122: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0800 - accuracy: 0.9729 - val_loss: 34.4566 - val_accuracy: 0.5735 - lr: 1.8759e-07
# Epoch 123/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9723
# Epoch 123: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0793 - accuracy: 0.9724 - val_loss: 33.2326 - val_accuracy: 0.5735 - lr: 1.8759e-07
# Epoch 124/200
# 3833/3834 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9734
# Epoch 124: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0781 - accuracy: 0.9734 - val_loss: 37.2414 - val_accuracy: 0.5652 - lr: 1.8759e-07
# Epoch 125/200
# 3828/3834 [============================>.] - ETA: 0s - loss: 0.0792 - accuracy: 0.9734
# Epoch 125: ReduceLROnPlateau reducing learning rate to 3.7518080375775756e-08.
#
# Epoch 125: loss did not improve from 0.60817
# 3834/3834 [==============================] - 20s 5ms/step - loss: 0.0794 - accuracy: 0.9731 - val_loss: 41.2735 - val_accuracy: 0.5527 - lr: 1.8759e-07
# Epoch 125: early stopping

# %%
model.evaluate(X_test, y_test)
# Out:
# 150/150 [==============================] - 1s 3ms/step - loss: 87.2971 - accuracy: 0.5608
# [87.29711151123047, 0.5608178377151489]

# %%
predictions = model.predict(X_test).astype("int").flatten()
# Out:
# 150/150 [==============================] - 1s 2ms/step

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predictions, normalize='true', values_format='.0%')
plt.show()

# %%
print(f'Recall: {recall_score(y_test, predictions)}')
print(f'Precision: {precision_score(y_test, predictions)}')
# Out:
# Recall: 0.2958139534883721
# Precision: 0.4598698481561822

# %%
model.save(f'{modelpath}/cnnTradingPetrobras.h5')
